# %% [markdown]
# # The Sparse Mixture-of-Experts Layer

# %% [markdown]
# The [Sparse Mixture-of-Experts](https://arxiv.org/abs/1701.06538) (MoE) layer computes a **sparse** combination of expert modules for a given input.
#
# In this notebook, we provide a walkthorugh for implementing a sparse MoE layer and then show how you can include it in a character-level language model.
#
# This notebook is inspired by the makeMoE blog post, available at: https://huggingface.co/blog/AviSoori1x/makemoe-from-scratch.
#
# *The following implementations are mearly illustrative and didactic, often at the cost of performance.*

# %% [markdown]
# ## Part I: The Sparse MoE layer

# %% [markdown]
# > MoE layers combine the output of $n$ expert networks $\{E_1, \dots, E_n\}$ using a gating function $G$. The following equation defines an MoE layer. It maps an input vector $x$ to a weighted sum of the experts' outputs, where the gating function assigns the weights.
# >
# > $$
# > y = \sum_{i=1}^{n} G(x)_i E_i(x)
# > $$
# >
# > Sparse MoE layers rely on **sparse gating functions**, which only select a subset of experts. This can be achieved with a sparse gating vector *i.e.*, by assigning some experts 0 weight. Importantly, the *computation for experts assigned zero weight can be skipped*.

# %% [markdown]
# At the core of the sparse MoE layer is its sparse gating (or routing) function, which assigns a weight to each expert.
#
# > The sparse gating function $G : \mathbb{R}^N → \mathbb{R}^E$ maps an input token to a sparse vector with the weight scores of each expert.
#
# A common approach is to learn a linear transformation $W_g^{N \times E}$ which maps the input token representations to affinity scores for each expert and then select the highest k:
#
# $$
# G(x) = Softmax(KeepTopK(W_g x, k)), \text{where} \\
# KeepTopK(z, k)_i =
# \begin{cases}
#   z_i & \text{if $z_i$ in the top $k$ elements of $z$} \\
#   -\inf & \text{otherwise}
# \end{cases}
# $$

# %%
import torch
import torch.nn as nn

def topk_scores(gate: nn.Linear, k: int, x: torch.Tensor):
    raw_scores = gate(x)
    scores = keep_topk(raw_scores, k)
    scores = torch.softmax(scores, dim=-1, dtype=torch.float32)
    return scores

def keep_topk(scores: torch.Tensor, k: int) -> torch.Tensor:
    _, topk_indices = scores.topk(k, dim=-1)
    assignment = torch.zeros_like(scores, dtype=torch.bool)
    assignment.scatter_(-1, topk_indices, True)
    return torch.where(assignment, scores, float("-inf"))

# %% [markdown]
# Another component of sparse MoE layers are the experts.
#
# > An expert $E : \mathbb{R}^N → \mathbb{R}^N$ learns a (usually) non-linear transformation of the input x.
#
# In this notebook, we will use a two-layer MLP.

# %%
def make_expert(hidden_size):
    return nn.Sequential(
        nn.Linear(hidden_size, 4 * hidden_size),
        nn.GELU(),
        nn.Linear(4 * hidden_size, hidden_size),
    )

# %% [markdown]
# One important aspect of constructing the experts is ensuring that they only compute the output representations for selected inputs.

# %%
def run_expert(expert: nn.Module, expert_scores: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
    # Select the inputs to compute and totally skip the expert if it was not selected.
    selected_x = x[expert_scores > 0]
    if len(selected_x) == 0:
        return None

    weights = expert_scores[expert_scores > 0].unsqueeze(-1)

    return weights * expert(selected_x)

# %% [markdown]
# Putting everything together, we can run a sparse MoE layer by first obtaining the scores and then computing the expert outputs for the selected tokens.

# %%
class MoELayer(nn.Module):
    def __init__(self, *, hidden_size: int, num_experts: int, k: int):
        super().__init__()
        self.gate = nn.Linear(hidden_size, num_experts)
        self.experts = nn.ModuleList(
            [make_expert(hidden_size) for _ in range(num_experts)]
        )
        self.k = k

    def forward(self, x: torch.Tensor):
        # Flatten all dimensions (e.g batch, seq len)
        x_flat = x.view(-1, x.size(-1))

        scores = topk_scores(self.gate, self.k, x_flat)

        outputs = torch.zeros_like(x_flat)
        for i, expert in enumerate(self.experts):
            expert_scores = scores[:, i]

            expert_outputs = run_expert(expert, expert_scores, x_flat)
            if expert_outputs is None:
                continue

            outputs[expert_scores > 0] += expert_outputs

        # Recover original dimensions
        outputs = outputs.view_as(x)

        return outputs

# %% [markdown]
# ## Part II: The training data

# %% [markdown]
# With the sparse MoE layer implemented, we will move towards developing a character level model using that layer. The model will be trained on text from Shakespeare, available at [https://raw.githubusercontent.com/AviSoori1x/makeMoE/main/input.txt
# ](https://raw.githubusercontent.com/AviSoori1x/makeMoE/main/input.txt
# ).

# %% [markdown]
# We will start by downloading and inspecting the data.

# %%
# Downloading the tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/AviSoori1x/makeMoE/main/input.txt

# read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print("Length in characters: ", len(text))

# let's look at the first 100 characters
print("First 100 characters", "-" * 50)
print(text[:100])
# Out:
# --2024-10-02 10:29:14--  https://raw.githubusercontent.com/AviSoori1x/makeMoE/main/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.3’
#
# input.txt.3         100%[===================>]   1.06M  --.-KB/s    in 0.007s
#
# 2024-10-02 10:29:15 (156 MB/s) - ‘input.txt.3’ saved [1115394/1115394]
#
# Length in characters:  1115394
# First 100 characters --------------------------------------------------
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You

# %% [markdown]
# From here, we can create the model vocabulary, which maps the characters into token ids.

# %%
class Vocabulary:

  def __init__(self, text: str):
    chars = set(text)
    self.ctoi = {c: i for i, c in enumerate(chars)}
    self.itoc = {v: k for k, v in self.ctoi.items()}

  def encode(self, text: str) -> list[int]:
    return [self.ctoi[t] for t in text]

  def decode(self, ids: list[int]) -> str:
    return "".join(self.itoc[i] for i in ids)

  def __len__(self):
    return len(self.ctoi)

  def __str__(self):
    return f"Vocabulary[size={len(self)}]{self.ctoi}"

# %% [markdown]
# We can train the vocabulary on the whole training set and some light testing to check that everything is working as expected.

# %%
vocab = Vocabulary(text)
print(vocab)

# Test if encoding/decoding work
first_chars = text[:1000]
encoded = vocab.encode(first_chars)
decoded = vocab.decode(encoded)
assert first_chars == decoded
# Out:
# Vocabulary[size=65]{'N': 0, 'j': 1, '\n': 2, 'U': 3, '$': 4, 'c': 5, '-': 6, 'y': 7, 'k': 8, 't': 9, 'v': 10, 'K': 11, 'S': 12, 'w': 13, 'z': 14, 'f': 15, 'p': 16, 'h': 17, '?': 18, 'M': 19, 'I': 20, 'Q': 21, 'X': 22, 'b': 23, '!': 24, 'F': 25, 'O': 26, 'r': 27, ' ': 28, 'u': 29, 'W': 30, '.': 31, ':': 32, 'Z': 33, ',': 34, 'd': 35, 'o': 36, 'H': 37, 'V': 38, 'B': 39, 'T': 40, 'n': 41, 'a': 42, 'L': 43, '3': 44, 'J': 45, 'x': 46, 'D': 47, 'g': 48, 'Y': 49, ';': 50, 's': 51, 'l': 52, 'm': 53, 'R': 54, 'G': 55, 'P': 56, '&': 57, 'i': 58, 'E': 59, 'e': 60, "'": 61, 'C': 62, 'q': 63, 'A': 64}

# %% [markdown]
# Afterwards, we can encode the data as a tensor and create a train and validation split.

# %%
val_ratio = 0.05

# Encode all text
encoded_text = torch.tensor(vocab.encode(text))
print("Total tokens:", encoded_text.size(0))
# Split into train and validation
val_size = int(val_ratio*len(encoded_text))

encoded_train = encoded_text[:-val_size]
encoded_val = encoded_text[-val_size:]
print("Train tokens:", encoded_train.size(0))
print("Val tokens: ", encoded_val.size(0))
# Out:
# Total tokens: 1115394
# Train tokens: 1059625
# Val tokens:  55769

# %% [markdown]
# From here, we can create the dataset class to iterate the data. Each record will be a chunk of adjacent tokens and the model will learn to predict the next token from the previous ones.

# %%
import torch.utils.data

# Predict on block_size contiguous tokens
seq_len = 64


class ShakespearDataset(torch.utils.data.Dataset):

  def __init__(self, data: torch.Tensor, seq_len: int):
    self.data = data
    self.seq_len = seq_len


  def __getitem__(self, i: int) -> torch.Tensor:
    # Account for extra one in LM offset
    data = self.data[i:i + self.seq_len + 1]
    x = data[:-1]
    y = data[1:]
    return x, y

  def __len__(self):
    return len(self.data) - self.seq_len - 1

train = ShakespearDataset(encoded_train, seq_len)
val = ShakespearDataset(encoded_val, seq_len)
print("Train size:", len(train), ", val size:", len(val))
# Out:
# Train size: 1059560 , val size: 55704

# %% [markdown]
# ## Part III: The Mixture-of-Experts Model

# %% [markdown]
# Finally, we can create the transformer model with the sparse MoE layer replacing the usual feed forward network.
#
# We start by defining the model configuration.
#
# *This network implementation is mearly illustrative.*

# %%
import dataclasses

@dataclasses.dataclass
class Config:
  seq_len: int = seq_len
  n_layers: int = 6
  n_heads: int = 6
  hidden_size: int = 192
  head_size: int = 32
  vocab_size: int = len(vocab)

  k: int = 1
  normalize_scores: int = True
  n_experts: int = 8

# %% [markdown]
# Afterwards, we define the self-attention mechanism.

# %%
import einops
import torch.nn as nn
import torch.nn.functional as F

class MultiHeadAttention(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.config = config
    # We have n_head projections, each projecting to head_dim for the queries, keys and values.
    self.queries_proj = nn.Linear(config.hidden_size, config.n_heads * config.head_size)
    self.keys_proj = nn.Linear(config.hidden_size, config.n_heads * config.head_size)
    self.values_proj = nn.Linear(config.hidden_size, config.n_heads * config.head_size)
    self.out_proj = nn.Linear(config.n_heads * config.head_size, config.hidden_size)

  def forward(self, x: torch.Tensor, is_causal: bool = True, use_sdpa: bool = True):
    _, T, _ = x.size()
    n_heads, head_dim = self.config.n_heads, self.config.head_size

    # Compute projections and split by queries, keys and values.
    q, k, v = self.queries_proj(x), self.keys_proj(x), self.values_proj(x)

    if use_sdpa:
      q = einops.rearrange(q, "b t (head proj) -> b head t proj", head=n_heads, proj=head_dim)
      k = einops.rearrange(k, "b t (head proj) -> b head t proj", head=n_heads, proj=head_dim)
      v = einops.rearrange(v, "b t (head proj) -> b head t proj", head=n_heads, proj=head_dim)

      out = F.scaled_dot_product_attention(q, k, v, dropout_p=0.0, is_causal=is_causal)
    else:
      q = einops.rearrange(q, "b t (head proj) -> b t head proj", head=n_heads, proj=head_dim)
      k = einops.rearrange(k, "b t (head proj) -> b t head proj", head=n_heads, proj=head_dim)
      v = einops.rearrange(v, "b t (head proj) -> b t head proj", head=n_heads, proj=head_dim)

      # Compute unnormalized attention scores
      a = einops.einsum(q, k, "b query head proj, b key head proj -> b head query key") # (b, n_heads, T, T)
      a = a / head_dim ** 0.5 # (b, n_heads, T, T)
      # Mask future tokens
      if is_causal:
        mask = torch.tril(torch.ones((T, T), dtype=torch.bool, device=x.device))
        a = torch.masked_fill(a, mask == 0, float("-inf")) # (b, n_heads, T, T)
      # Compute attention weights
      a = torch.softmax(a, dim=-1) # (b, n_heads, T, T)

      # Compute attention values
      out = einops.einsum(a, v, "b head query key, batch key head proj -> b head query proj")

    # Reorder to have all head values for token together
    out = einops.rearrange(out, "b head time proj -> b time (head proj)")

    # Compute the final projection
    out = self.out_proj(out)
    return out

config = Config()
attn = MultiHeadAttention(config)
input = torch.rand(4, 8, config.hidden_size)
out = attn(input, is_causal=True)
out.size()
# Out:
# torch.Size([4, 8, 192])

# %%
class Block(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.attn = MultiHeadAttention(config)
    self.attn_norm = nn.LayerNorm(config.hidden_size)
    self.mlp = MoELayer(
        hidden_size=config.hidden_size,
        num_experts=config.n_experts,
        k=config.k,
    )
    self.mlp_norm = nn.LayerNorm(config.hidden_size)

  def forward(self, x: torch.Tensor) -> torch.Tensor:
    h = self.attn_norm(x)
    h = self.attn(h, use_sdpa=True)
    x = x + h
    h = self.mlp_norm(x)
    h = self.mlp(h)
    x = x + h
    return x


class Transformer(nn.Module):

  def __init__(self, config: Config):
    super().__init__()
    self.tok_emb = nn.Embedding(config.vocab_size, config.hidden_size)
    self.pos_emb = nn.Embedding(config.seq_len, config.hidden_size)
    self.blocks = nn.ModuleList(Block(config) for _ in range(config.n_layers))
    self.final_norm = nn.LayerNorm(config.hidden_size)
    self.lm_head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)

  def forward(self, tokens: torch.Tensor) -> torch.Tensor:
    tok_emb = self.tok_emb(tokens)
    pos_emb = self._get_pos_embeddings(tokens)

    hidden_states = tok_emb + pos_emb

    for block in self.blocks:
      hidden_states = block(hidden_states)

    hidden_states = self.final_norm(hidden_states)
    logits = self.lm_head(hidden_states)
    return logits

  def _get_pos_embeddings(self, tokens: torch.Tensor) -> torch.Tensor:
    batch_size, seq_len = tokens.size()
    pos_idx = torch.arange(seq_len, device=tokens.device)
    pos_emb = self.pos_emb(pos_idx)
    return pos_emb

# %%
def train_step(
    model: Transformer,
    optimizer: torch.optim.Optimizer,
    scaler,
    device_type: str,
    x: torch.Tensor,
    y: torch.Tensor,
):
  with torch.autocast(device_type=device_type, dtype=torch.float16):
    logits = model(x)
    logits = einops.rearrange(logits, "b s e -> (b s) e")
    y = einops.rearrange(y, "b s -> (b s)")
    loss = F.cross_entropy(logits, y)

  scaler.scale(loss).backward()

  scaler.step(optimizer)

  scaler.update()

  optimizer.zero_grad(set_to_none=True)
  return loss.item()

# %%
import functools
import torch
import torch.cuda

import torch.optim
import time

from typing import Literal
torch.manual_seed(42)


device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cpu":
  print("WARNING: Using cpu device, training will be slow")

train_dataloader = torch.utils.data.DataLoader(
    train, batch_size=64, shuffle=True, pin_memory=True, num_workers=2, prefetch_factor=2,
)

config = Config()
model = Transformer(config)

model_params = sum(p.numel() for p in model.parameters())
print("Total parameters:", (model_params / 1e6), "M")

optimizer = torch.optim.AdamW(
    model.parameters(), lr=1e-3, weight_decay=0.1, betas=(0.9, 0.95),
)
scaler = torch.amp.GradScaler()
model.to(device)

num_epochs = 1
step_time = 0
step_count = 0
token_count = 0
start_time = time.time()

num_steps = 10000
dataiter = iter(train_dataloader)
for step in range(1, num_steps + 1):
  x, y = next(dataiter)
  start = time.time()
  x, y = x.to(device), y.to(device)
  token_count += x.numel()
  loss = train_step(model, optimizer, scaler, device, x, y)
  step_time += time.time() - start
  step_count += 1
  if step % 10 == 0:
    completed = step / num_steps * 100
    step_avg = step_time / step_count
    ellapsed = time.time() - start_time
    tok_per_sec = token_count / ellapsed
    fmt_ellapsed = time.strftime("%H:%M:%S", time.gmtime(ellapsed))
    print(
        f"Step {step}/{num_steps} ({completed:.0f}%): "
        f"TrainTime={fmt_ellapsed}, "
        f"Loss={loss:.4f}, "
        f"TokensPerSec={tok_per_sec:.0f}, "
        f"AvgStepTime={step_avg:.2}s"
    )
# Out:
# Total parameters: 15.142704 M
# Step 10/10000 (0%): TrainTime=00:00:01, Loss=2.8247, TokensPerSec=24996, AvgStepTime=0.15s
# Step 20/10000 (0%): TrainTime=00:00:02, Loss=2.6095, TokensPerSec=28185, AvgStepTime=0.14s
# Step 30/10000 (0%): TrainTime=00:00:04, Loss=2.5605, TokensPerSec=29962, AvgStepTime=0.13s
# Step 40/10000 (0%): TrainTime=00:00:05, Loss=2.4793, TokensPerSec=30736, AvgStepTime=0.13s
# Step 50/10000 (0%): TrainTime=00:00:06, Loss=2.4451, TokensPerSec=29551, AvgStepTime=0.13s
# Step 60/10000 (1%): TrainTime=00:00:08, Loss=2.4691, TokensPerSec=30381, AvgStepTime=0.13s
# Step 70/10000 (1%): TrainTime=00:00:09, Loss=2.4879, TokensPerSec=30438, AvgStepTime=0.13s
# Step 80/10000 (1%): TrainTime=00:00:11, Loss=2.4157, TokensPerSec=29593, AvgStepTime=0.14s
# Step 90/10000 (1%): TrainTime=00:00:12, Loss=2.3974, TokensPerSec=29990, AvgStepTime=0.13s
# Step 100/10000 (1%): TrainTime=00:00:13, Loss=2.3939, TokensPerSec=30506, AvgStepTime=0.13s
# Step 110/10000 (1%): TrainTime=00:00:14, Loss=2.3415, TokensPerSec=30937, AvgStepTime=0.13s
# Step 120/10000 (1%): TrainTime=00:00:15, Loss=2.2855, TokensPerSec=31182, AvgStepTime=0.13s
# Step 130/10000 (1%): TrainTime=00:00:16, Loss=2.2384, TokensPerSec=31440, AvgStepTime=0.13s
# Step 140/10000 (1%): TrainTime=00:00:18, Loss=2.2423, TokensPerSec=31708, AvgStepTime=0.13s
# Step 150/10000 (2%): TrainTime=00:00:19, Loss=2.1829, TokensPerSec=31964, AvgStepTime=0.13s
# Step 160/10000 (2%): TrainTime=00:00:20, Loss=2.1819, TokensPerSec=32178, AvgStepTime=0.13s
# Step 170/10000 (2%): TrainTime=00:00:21, Loss=2.1704, TokensPerSec=32205, AvgStepTime=0.13s
# Step 180/10000 (2%): TrainTime=00:00:23, Loss=2.1281, TokensPerSec=31735, AvgStepTime=0.13s
# Step 190/10000 (2%): TrainTime=00:00:24, Loss=2.1299, TokensPerSec=31701, AvgStepTime=0.13s
# Step 200/10000 (2%): TrainTime=00:00:25, Loss=2.0892, TokensPerSec=31862, AvgStepTime=0.13s
# Step 210/10000 (2%): TrainTime=00:00:26, Loss=2.0750, TokensPerSec=32026, AvgStepTime=0.13s
# Step 220/10000 (2%): TrainTime=00:00:28, Loss=2.0817, TokensPerSec=32168, AvgStepTime=0.13s
# Step 230/10000 (2%): TrainTime=00:00:29, Loss=2.0131, TokensPerSec=32278, AvgStepTime=0.13s
# Step 240/10000 (2%): TrainTime=00:00:30, Loss=1.9780, TokensPerSec=32388, AvgStepTime=0.12s
# Step 250/10000 (2%): TrainTime=00:00:31, Loss=1.9630, TokensPerSec=32488, AvgStepTime=0.12s
# Step 260/10000 (3%): TrainTime=00:00:32, Loss=1.9595, TokensPerSec=32582, AvgStepTime=0.12s
# Step 270/10000 (3%): TrainTime=00:00:33, Loss=1.9434, TokensPerSec=32617, AvgStepTime=0.12s
# Step 280/10000 (3%): TrainTime=00:00:35, Loss=1.9068, TokensPerSec=32329, AvgStepTime=0.13s
# Step 290/10000 (3%): TrainTime=00:00:36, Loss=1.9191, TokensPerSec=32178, AvgStepTime=0.13s
# Step 300/10000 (3%): TrainTime=00:00:38, Loss=1.8851, TokensPerSec=32255, AvgStepTime=0.13s
# Step 310/10000 (3%): TrainTime=00:00:39, Loss=1.9128, TokensPerSec=32322, AvgStepTime=0.13s
# Step 320/10000 (3%): TrainTime=00:00:40, Loss=1.8426, TokensPerSec=32374, AvgStepTime=0.13s
# Step 330/10000 (3%): TrainTime=00:00:41, Loss=1.8421, TokensPerSec=32451, AvgStepTime=0.12s
# Step 340/10000 (3%): TrainTime=00:00:42, Loss=1.8617, TokensPerSec=32510, AvgStepTime=0.12s
# Step 350/10000 (4%): TrainTime=00:00:43, Loss=1.8534, TokensPerSec=32585, AvgStepTime=0.12s
# Step 360/10000 (4%): TrainTime=00:00:45, Loss=1.7927, TokensPerSec=32645, AvgStepTime=0.12s
# Step 370/10000 (4%): TrainTime=00:00:46, Loss=1.8463, TokensPerSec=32629, AvgStepTime=0.12s
# Step 380/10000 (4%): TrainTime=00:00:48, Loss=1.7732, TokensPerSec=32405, AvgStepTime=0.13s
# Step 390/10000 (4%): TrainTime=00:00:49, Loss=1.7780, TokensPerSec=32332, AvgStepTime=0.13s
# Step 400/10000 (4%): TrainTime=00:00:50, Loss=1.7725, TokensPerSec=32387, AvgStepTime=0.13s
# Step 410/10000 (4%): TrainTime=00:00:51, Loss=1.7633, TokensPerSec=32434, AvgStepTime=0.13s
# Step 420/10000 (4%): TrainTime=00:00:52, Loss=1.7877, TokensPerSec=32471, AvgStepTime=0.12s
# Step 430/10000 (4%): TrainTime=00:00:54, Loss=1.7683, TokensPerSec=32545, AvgStepTime=0.12s
# Step 440/10000 (4%): TrainTime=00:00:55, Loss=1.7046, TokensPerSec=32598, AvgStepTime=0.12s
# Step 450/10000 (4%): TrainTime=00:00:56, Loss=1.7519, TokensPerSec=32674, AvgStepTime=0.12s
# Step 460/10000 (5%): TrainTime=00:00:57, Loss=1.7743, TokensPerSec=32743, AvgStepTime=0.12s
# Step 470/10000 (5%): TrainTime=00:00:58, Loss=1.7632, TokensPerSec=32788, AvgStepTime=0.12s
# Step 480/10000 (5%): TrainTime=00:01:00, Loss=1.6751, TokensPerSec=32620, AvgStepTime=0.12s
# Step 490/10000 (5%): TrainTime=00:01:01, Loss=1.6745, TokensPerSec=32524, AvgStepTime=0.12s
# Step 500/10000 (5%): TrainTime=00:01:02, Loss=1.6660, TokensPerSec=32562, AvgStepTime=0.12s
# Step 510/10000 (5%): TrainTime=00:01:04, Loss=1.7171, TokensPerSec=32593, AvgStepTime=0.12s
# Step 520/10000 (5%): TrainTime=00:01:05, Loss=1.7143, TokensPerSec=32631, AvgStepTime=0.12s
# Step 530/10000 (5%): TrainTime=00:01:06, Loss=1.6895, TokensPerSec=32659, AvgStepTime=0.12s
# Step 540/10000 (5%): TrainTime=00:01:07, Loss=1.6663, TokensPerSec=32696, AvgStepTime=0.12s
# Step 550/10000 (6%): TrainTime=00:01:08, Loss=1.6241, TokensPerSec=32740, AvgStepTime=0.12s
# Step 560/10000 (6%): TrainTime=00:01:09, Loss=1.6746, TokensPerSec=32783, AvgStepTime=0.12s
# Step 570/10000 (6%): TrainTime=00:01:11, Loss=1.6638, TokensPerSec=32663, AvgStepTime=0.12s
# Step 580/10000 (6%): TrainTime=00:01:13, Loss=1.6655, TokensPerSec=32178, AvgStepTime=0.13s
# Step 590/10000 (6%): TrainTime=00:01:15, Loss=1.6372, TokensPerSec=32197, AvgStepTime=0.13s
# Step 600/10000 (6%): TrainTime=00:01:16, Loss=1.6038, TokensPerSec=32227, AvgStepTime=0.13s
# Step 610/10000 (6%): TrainTime=00:01:17, Loss=1.6644, TokensPerSec=32272, AvgStepTime=0.13s
# Step 620/10000 (6%): TrainTime=00:01:18, Loss=1.6346, TokensPerSec=32318, AvgStepTime=0.13s
# Step 630/10000 (6%): TrainTime=00:01:19, Loss=1.6516, TokensPerSec=32359, AvgStepTime=0.13s
# Step 640/10000 (6%): TrainTime=00:01:20, Loss=1.6366, TokensPerSec=32405, AvgStepTime=0.13s
# Step 650/10000 (6%): TrainTime=00:01:22, Loss=1.6564, TokensPerSec=32448, AvgStepTime=0.13s
# Step 660/10000 (7%): TrainTime=00:01:23, Loss=1.6387, TokensPerSec=32493, AvgStepTime=0.13s
# Step 670/10000 (7%): TrainTime=00:01:24, Loss=1.6480, TokensPerSec=32477, AvgStepTime=0.13s
# Step 680/10000 (7%): TrainTime=00:01:26, Loss=1.6403, TokensPerSec=32341, AvgStepTime=0.13s
# Step 690/10000 (7%): TrainTime=00:01:27, Loss=1.5874, TokensPerSec=32347, AvgStepTime=0.13s
# Step 700/10000 (7%): TrainTime=00:01:28, Loss=1.5533, TokensPerSec=32391, AvgStepTime=0.13s
# Step 710/10000 (7%): TrainTime=00:01:29, Loss=1.6285, TokensPerSec=32430, AvgStepTime=0.13s
# Step 720/10000 (7%): TrainTime=00:01:30, Loss=1.6235, TokensPerSec=32472, AvgStepTime=0.13s
# Step 730/10000 (7%): TrainTime=00:01:31, Loss=1.6137, TokensPerSec=32501, AvgStepTime=0.13s
# Step 740/10000 (7%): TrainTime=00:01:33, Loss=1.5561, TokensPerSec=32542, AvgStepTime=0.12s
# Step 750/10000 (8%): TrainTime=00:01:34, Loss=1.5726, TokensPerSec=32582, AvgStepTime=0.12s
# Step 760/10000 (8%): TrainTime=00:01:35, Loss=1.5632, TokensPerSec=32615, AvgStepTime=0.12s
# Step 770/10000 (8%): TrainTime=00:01:36, Loss=1.6173, TokensPerSec=32608, AvgStepTime=0.12s
# Step 780/10000 (8%): TrainTime=00:01:38, Loss=1.5506, TokensPerSec=32487, AvgStepTime=0.13s
# Step 790/10000 (8%): TrainTime=00:01:39, Loss=1.6358, TokensPerSec=32447, AvgStepTime=0.13s
# Step 800/10000 (8%): TrainTime=00:01:40, Loss=1.5719, TokensPerSec=32469, AvgStepTime=0.13s
# Step 810/10000 (8%): TrainTime=00:01:42, Loss=1.6152, TokensPerSec=32493, AvgStepTime=0.13s
# Step 820/10000 (8%): TrainTime=00:01:43, Loss=1.5275, TokensPerSec=32512, AvgStepTime=0.12s
# Step 830/10000 (8%): TrainTime=00:01:44, Loss=1.5344, TokensPerSec=32531, AvgStepTime=0.12s
# Step 840/10000 (8%): TrainTime=00:01:45, Loss=1.5644, TokensPerSec=32556, AvgStepTime=0.12s
# Step 850/10000 (8%): TrainTime=00:01:46, Loss=1.5579, TokensPerSec=32585, AvgStepTime=0.12s
# Step 860/10000 (9%): TrainTime=00:01:48, Loss=1.4982, TokensPerSec=32613, AvgStepTime=0.12s
# Step 870/10000 (9%): TrainTime=00:01:49, Loss=1.5128, TokensPerSec=32619, AvgStepTime=0.12s
# Step 880/10000 (9%): TrainTime=00:01:50, Loss=1.5434, TokensPerSec=32513, AvgStepTime=0.13s
# Step 890/10000 (9%): TrainTime=00:01:52, Loss=1.5475, TokensPerSec=32459, AvgStepTime=0.13s
# Step 900/10000 (9%): TrainTime=00:01:53, Loss=1.5676, TokensPerSec=32385, AvgStepTime=0.13s
# Step 910/10000 (9%): TrainTime=00:01:55, Loss=1.5289, TokensPerSec=32411, AvgStepTime=0.13s
# Step 920/10000 (9%): TrainTime=00:01:56, Loss=1.5278, TokensPerSec=32342, AvgStepTime=0.13s
# Step 930/10000 (9%): TrainTime=00:01:58, Loss=1.5376, TokensPerSec=32229, AvgStepTime=0.13s
# Step 940/10000 (9%): TrainTime=00:01:59, Loss=1.5687, TokensPerSec=32263, AvgStepTime=0.13s
# Step 950/10000 (10%): TrainTime=00:02:00, Loss=1.4796, TokensPerSec=32293, AvgStepTime=0.13s
# Step 960/10000 (10%): TrainTime=00:02:02, Loss=1.5322, TokensPerSec=32186, AvgStepTime=0.13s
# Step 970/10000 (10%): TrainTime=00:02:04, Loss=1.4810, TokensPerSec=32002, AvgStepTime=0.13s
# Step 980/10000 (10%): TrainTime=00:02:05, Loss=1.5073, TokensPerSec=32020, AvgStepTime=0.13s
# Step 990/10000 (10%): TrainTime=00:02:06, Loss=1.5158, TokensPerSec=31995, AvgStepTime=0.13s
# Step 1000/10000 (10%): TrainTime=00:02:07, Loss=1.5003, TokensPerSec=32010, AvgStepTime=0.13s
# Step 1010/10000 (10%): TrainTime=00:02:09, Loss=1.5025, TokensPerSec=31992, AvgStepTime=0.13s
# Step 1020/10000 (10%): TrainTime=00:02:10, Loss=1.4985, TokensPerSec=32022, AvgStepTime=0.13s
# Step 1030/10000 (10%): TrainTime=00:02:11, Loss=1.5260, TokensPerSec=32053, AvgStepTime=0.13s
# Step 1040/10000 (10%): TrainTime=00:02:12, Loss=1.5084, TokensPerSec=32077, AvgStepTime=0.13s
# Step 1050/10000 (10%): TrainTime=00:02:13, Loss=1.5025, TokensPerSec=32100, AvgStepTime=0.13s
# Step 1060/10000 (11%): TrainTime=00:02:15, Loss=1.4925, TokensPerSec=32024, AvgStepTime=0.13s
# Step 1070/10000 (11%): TrainTime=00:02:17, Loss=1.4929, TokensPerSec=31961, AvgStepTime=0.13s
# Step 1080/10000 (11%): TrainTime=00:02:18, Loss=1.5012, TokensPerSec=31992, AvgStepTime=0.13s
# Step 1090/10000 (11%): TrainTime=00:02:19, Loss=1.4799, TokensPerSec=32026, AvgStepTime=0.13s
# Step 1100/10000 (11%): TrainTime=00:02:20, Loss=1.4585, TokensPerSec=32060, AvgStepTime=0.13s
# Step 1110/10000 (11%): TrainTime=00:02:21, Loss=1.4562, TokensPerSec=32087, AvgStepTime=0.13s
# Step 1120/10000 (11%): TrainTime=00:02:22, Loss=1.4806, TokensPerSec=32114, AvgStepTime=0.13s
# Step 1130/10000 (11%): TrainTime=00:02:23, Loss=1.4909, TokensPerSec=32146, AvgStepTime=0.13s
# Step 1140/10000 (11%): TrainTime=00:02:25, Loss=1.4772, TokensPerSec=32167, AvgStepTime=0.13s
# Step 1150/10000 (12%): TrainTime=00:02:26, Loss=1.4678, TokensPerSec=32198, AvgStepTime=0.13s
# Step 1160/10000 (12%): TrainTime=00:02:27, Loss=1.5086, TokensPerSec=32165, AvgStepTime=0.13s
# Step 1170/10000 (12%): TrainTime=00:02:29, Loss=1.4217, TokensPerSec=32080, AvgStepTime=0.13s
# Step 1180/10000 (12%): TrainTime=00:02:30, Loss=1.5173, TokensPerSec=32106, AvgStepTime=0.13s
# Step 1190/10000 (12%): TrainTime=00:02:31, Loss=1.4775, TokensPerSec=32129, AvgStepTime=0.13s
# Step 1200/10000 (12%): TrainTime=00:02:32, Loss=1.4859, TokensPerSec=32152, AvgStepTime=0.13s
# Step 1210/10000 (12%): TrainTime=00:02:34, Loss=1.4693, TokensPerSec=32177, AvgStepTime=0.13s
# Step 1220/10000 (12%): TrainTime=00:02:35, Loss=1.4279, TokensPerSec=32195, AvgStepTime=0.13s
# Step 1230/10000 (12%): TrainTime=00:02:36, Loss=1.4693, TokensPerSec=32220, AvgStepTime=0.13s
# Step 1240/10000 (12%): TrainTime=00:02:37, Loss=1.4817, TokensPerSec=32233, AvgStepTime=0.13s
# Step 1250/10000 (12%): TrainTime=00:02:38, Loss=1.4570, TokensPerSec=32253, AvgStepTime=0.13s
# Step 1260/10000 (13%): TrainTime=00:02:40, Loss=1.4863, TokensPerSec=32221, AvgStepTime=0.13s
# Step 1270/10000 (13%): TrainTime=00:02:42, Loss=1.4596, TokensPerSec=32093, AvgStepTime=0.13s
# Step 1280/10000 (13%): TrainTime=00:02:43, Loss=1.4703, TokensPerSec=32115, AvgStepTime=0.13s
# Step 1290/10000 (13%): TrainTime=00:02:44, Loss=1.4914, TokensPerSec=32136, AvgStepTime=0.13s
# Step 1300/10000 (13%): TrainTime=00:02:45, Loss=1.4471, TokensPerSec=32157, AvgStepTime=0.13s
# Step 1310/10000 (13%): TrainTime=00:02:46, Loss=1.4847, TokensPerSec=32180, AvgStepTime=0.13s
# Step 1320/10000 (13%): TrainTime=00:02:47, Loss=1.4721, TokensPerSec=32203, AvgStepTime=0.13s
# Step 1330/10000 (13%): TrainTime=00:02:49, Loss=1.4221, TokensPerSec=32218, AvgStepTime=0.13s
# Step 1340/10000 (13%): TrainTime=00:02:50, Loss=1.3987, TokensPerSec=32237, AvgStepTime=0.13s
# Step 1350/10000 (14%): TrainTime=00:02:51, Loss=1.4033, TokensPerSec=32249, AvgStepTime=0.13s
# Step 1360/10000 (14%): TrainTime=00:02:52, Loss=1.4542, TokensPerSec=32213, AvgStepTime=0.13s
# Step 1370/10000 (14%): TrainTime=00:02:54, Loss=1.4253, TokensPerSec=32147, AvgStepTime=0.13s
# Step 1380/10000 (14%): TrainTime=00:02:55, Loss=1.3662, TokensPerSec=32160, AvgStepTime=0.13s
# Step 1390/10000 (14%): TrainTime=00:02:56, Loss=1.3844, TokensPerSec=32180, AvgStepTime=0.13s
# Step 1400/10000 (14%): TrainTime=00:02:58, Loss=1.3827, TokensPerSec=32197, AvgStepTime=0.13s
# Step 1410/10000 (14%): TrainTime=00:02:59, Loss=1.4560, TokensPerSec=32207, AvgStepTime=0.13s
# Step 1420/10000 (14%): TrainTime=00:03:00, Loss=1.4502, TokensPerSec=32217, AvgStepTime=0.13s
# Step 1430/10000 (14%): TrainTime=00:03:01, Loss=1.3911, TokensPerSec=32235, AvgStepTime=0.13s
# Step 1440/10000 (14%): TrainTime=00:03:02, Loss=1.4463, TokensPerSec=32254, AvgStepTime=0.13s
# Step 1450/10000 (14%): TrainTime=00:03:04, Loss=1.4212, TokensPerSec=32266, AvgStepTime=0.13s
# Step 1460/10000 (15%): TrainTime=00:03:05, Loss=1.4064, TokensPerSec=32238, AvgStepTime=0.13s
# Step 1470/10000 (15%): TrainTime=00:03:07, Loss=1.4460, TokensPerSec=32170, AvgStepTime=0.13s
# Step 1480/10000 (15%): TrainTime=00:03:08, Loss=1.3663, TokensPerSec=32183, AvgStepTime=0.13s
# Step 1490/10000 (15%): TrainTime=00:03:09, Loss=1.3613, TokensPerSec=32204, AvgStepTime=0.13s
# Step 1500/10000 (15%): TrainTime=00:03:10, Loss=1.3946, TokensPerSec=32221, AvgStepTime=0.13s
# Step 1510/10000 (15%): TrainTime=00:03:11, Loss=1.4345, TokensPerSec=32235, AvgStepTime=0.13s
# Step 1520/10000 (15%): TrainTime=00:03:13, Loss=1.3846, TokensPerSec=32253, AvgStepTime=0.13s
# Step 1530/10000 (15%): TrainTime=00:03:14, Loss=1.4226, TokensPerSec=32277, AvgStepTime=0.13s
# Step 1540/10000 (15%): TrainTime=00:03:15, Loss=1.4163, TokensPerSec=32289, AvgStepTime=0.13s
# Step 1550/10000 (16%): TrainTime=00:03:16, Loss=1.4501, TokensPerSec=32305, AvgStepTime=0.13s
# Step 1560/10000 (16%): TrainTime=00:03:17, Loss=1.4244, TokensPerSec=32287, AvgStepTime=0.13s
# Step 1570/10000 (16%): TrainTime=00:03:19, Loss=1.4331, TokensPerSec=32229, AvgStepTime=0.13s
# Step 1580/10000 (16%): TrainTime=00:03:20, Loss=1.4596, TokensPerSec=32243, AvgStepTime=0.13s
# Step 1590/10000 (16%): TrainTime=00:03:21, Loss=1.3985, TokensPerSec=32265, AvgStepTime=0.13s
# Step 1600/10000 (16%): TrainTime=00:03:23, Loss=1.4592, TokensPerSec=32283, AvgStepTime=0.13s
# Step 1610/10000 (16%): TrainTime=00:03:24, Loss=1.4272, TokensPerSec=32301, AvgStepTime=0.13s
# Step 1620/10000 (16%): TrainTime=00:03:25, Loss=1.3828, TokensPerSec=32318, AvgStepTime=0.13s
# Step 1630/10000 (16%): TrainTime=00:03:26, Loss=1.4683, TokensPerSec=32338, AvgStepTime=0.13s
# Step 1640/10000 (16%): TrainTime=00:03:27, Loss=1.4478, TokensPerSec=32353, AvgStepTime=0.13s
# Step 1650/10000 (16%): TrainTime=00:03:28, Loss=1.3977, TokensPerSec=32372, AvgStepTime=0.13s
# Step 1660/10000 (17%): TrainTime=00:03:30, Loss=1.4057, TokensPerSec=32366, AvgStepTime=0.13s
# Step 1670/10000 (17%): TrainTime=00:03:31, Loss=1.4228, TokensPerSec=32310, AvgStepTime=0.13s
# Step 1680/10000 (17%): TrainTime=00:03:32, Loss=1.3489, TokensPerSec=32309, AvgStepTime=0.13s
# Step 1690/10000 (17%): TrainTime=00:03:34, Loss=1.4304, TokensPerSec=32324, AvgStepTime=0.13s
# Step 1700/10000 (17%): TrainTime=00:03:35, Loss=1.4375, TokensPerSec=32338, AvgStepTime=0.13s
# Step 1710/10000 (17%): TrainTime=00:03:36, Loss=1.4163, TokensPerSec=32356, AvgStepTime=0.13s
# Step 1720/10000 (17%): TrainTime=00:03:37, Loss=1.3931, TokensPerSec=32372, AvgStepTime=0.13s
# Step 1730/10000 (17%): TrainTime=00:03:38, Loss=1.4326, TokensPerSec=32381, AvgStepTime=0.13s
# Step 1740/10000 (17%): TrainTime=00:03:40, Loss=1.3577, TokensPerSec=32395, AvgStepTime=0.13s
# Step 1750/10000 (18%): TrainTime=00:03:41, Loss=1.3336, TokensPerSec=32407, AvgStepTime=0.13s
# Step 1760/10000 (18%): TrainTime=00:03:42, Loss=1.4055, TokensPerSec=32412, AvgStepTime=0.13s
# Step 1770/10000 (18%): TrainTime=00:03:43, Loss=1.3608, TokensPerSec=32370, AvgStepTime=0.13s
# Step 1780/10000 (18%): TrainTime=00:03:45, Loss=1.3776, TokensPerSec=32350, AvgStepTime=0.13s
# Step 1790/10000 (18%): TrainTime=00:03:46, Loss=1.4019, TokensPerSec=32363, AvgStepTime=0.13s
# Step 1800/10000 (18%): TrainTime=00:03:47, Loss=1.3524, TokensPerSec=32376, AvgStepTime=0.13s
# Step 1810/10000 (18%): TrainTime=00:03:48, Loss=1.3781, TokensPerSec=32389, AvgStepTime=0.13s
# Step 1820/10000 (18%): TrainTime=00:03:50, Loss=1.3717, TokensPerSec=32404, AvgStepTime=0.13s
# Step 1830/10000 (18%): TrainTime=00:03:51, Loss=1.3414, TokensPerSec=32418, AvgStepTime=0.13s
# Step 1840/10000 (18%): TrainTime=00:03:52, Loss=1.3537, TokensPerSec=32434, AvgStepTime=0.13s
# Step 1850/10000 (18%): TrainTime=00:03:53, Loss=1.3629, TokensPerSec=32448, AvgStepTime=0.13s
# Step 1860/10000 (19%): TrainTime=00:03:54, Loss=1.3779, TokensPerSec=32459, AvgStepTime=0.13s
# Step 1870/10000 (19%): TrainTime=00:03:56, Loss=1.4132, TokensPerSec=32415, AvgStepTime=0.13s
# Step 1880/10000 (19%): TrainTime=00:03:57, Loss=1.3776, TokensPerSec=32393, AvgStepTime=0.13s
# Step 1890/10000 (19%): TrainTime=00:03:58, Loss=1.3626, TokensPerSec=32409, AvgStepTime=0.13s
# Step 1900/10000 (19%): TrainTime=00:04:00, Loss=1.3409, TokensPerSec=32424, AvgStepTime=0.13s
# Step 1910/10000 (19%): TrainTime=00:04:01, Loss=1.3539, TokensPerSec=32436, AvgStepTime=0.13s
# Step 1920/10000 (19%): TrainTime=00:04:02, Loss=1.3434, TokensPerSec=32446, AvgStepTime=0.13s
# Step 1930/10000 (19%): TrainTime=00:04:03, Loss=1.3457, TokensPerSec=32460, AvgStepTime=0.13s
# Step 1940/10000 (19%): TrainTime=00:04:04, Loss=1.3492, TokensPerSec=32478, AvgStepTime=0.13s
# Step 1950/10000 (20%): TrainTime=00:04:05, Loss=1.3545, TokensPerSec=32495, AvgStepTime=0.13s
# Step 1960/10000 (20%): TrainTime=00:04:06, Loss=1.4129, TokensPerSec=32510, AvgStepTime=0.13s
# Step 1970/10000 (20%): TrainTime=00:04:08, Loss=1.3648, TokensPerSec=32479, AvgStepTime=0.13s
# Step 1980/10000 (20%): TrainTime=00:04:10, Loss=1.3548, TokensPerSec=32435, AvgStepTime=0.13s
# Step 1990/10000 (20%): TrainTime=00:04:11, Loss=1.3785, TokensPerSec=32445, AvgStepTime=0.13s
# Step 2000/10000 (20%): TrainTime=00:04:12, Loss=1.3621, TokensPerSec=32459, AvgStepTime=0.13s
# Step 2010/10000 (20%): TrainTime=00:04:13, Loss=1.3884, TokensPerSec=32474, AvgStepTime=0.13s
# Step 2020/10000 (20%): TrainTime=00:04:14, Loss=1.3827, TokensPerSec=32486, AvgStepTime=0.13s
# Step 2030/10000 (20%): TrainTime=00:04:15, Loss=1.3396, TokensPerSec=32496, AvgStepTime=0.13s
# Step 2040/10000 (20%): TrainTime=00:04:17, Loss=1.3524, TokensPerSec=32509, AvgStepTime=0.13s
# Step 2050/10000 (20%): TrainTime=00:04:18, Loss=1.3579, TokensPerSec=32522, AvgStepTime=0.13s
# Step 2060/10000 (21%): TrainTime=00:04:19, Loss=1.3850, TokensPerSec=32537, AvgStepTime=0.13s
# Step 2070/10000 (21%): TrainTime=00:04:20, Loss=1.3527, TokensPerSec=32513, AvgStepTime=0.13s
# Step 2080/10000 (21%): TrainTime=00:04:22, Loss=1.3436, TokensPerSec=32474, AvgStepTime=0.13s
# Step 2090/10000 (21%): TrainTime=00:04:23, Loss=1.3403, TokensPerSec=32488, AvgStepTime=0.13s
# Step 2100/10000 (21%): TrainTime=00:04:24, Loss=1.3103, TokensPerSec=32502, AvgStepTime=0.13s
# Step 2110/10000 (21%): TrainTime=00:04:25, Loss=1.3241, TokensPerSec=32518, AvgStepTime=0.13s
# Step 2120/10000 (21%): TrainTime=00:04:26, Loss=1.2820, TokensPerSec=32534, AvgStepTime=0.13s
# Step 2130/10000 (21%): TrainTime=00:04:28, Loss=1.3341, TokensPerSec=32547, AvgStepTime=0.12s
# Step 2140/10000 (21%): TrainTime=00:04:29, Loss=1.3486, TokensPerSec=32565, AvgStepTime=0.12s
# Step 2150/10000 (22%): TrainTime=00:04:30, Loss=1.3638, TokensPerSec=32581, AvgStepTime=0.12s
# Step 2160/10000 (22%): TrainTime=00:04:31, Loss=1.3623, TokensPerSec=32596, AvgStepTime=0.12s
# Step 2170/10000 (22%): TrainTime=00:04:32, Loss=1.3758, TokensPerSec=32585, AvgStepTime=0.12s
# Step 2180/10000 (22%): TrainTime=00:04:34, Loss=1.3795, TokensPerSec=32545, AvgStepTime=0.13s
# Step 2190/10000 (22%): TrainTime=00:04:35, Loss=1.3767, TokensPerSec=32542, AvgStepTime=0.13s
# Step 2200/10000 (22%): TrainTime=00:04:36, Loss=1.3720, TokensPerSec=32555, AvgStepTime=0.12s
# Step 2210/10000 (22%): TrainTime=00:04:37, Loss=1.3890, TokensPerSec=32568, AvgStepTime=0.12s
# Step 2220/10000 (22%): TrainTime=00:04:39, Loss=1.3679, TokensPerSec=32581, AvgStepTime=0.12s
# Step 2230/10000 (22%): TrainTime=00:04:40, Loss=1.3545, TokensPerSec=32594, AvgStepTime=0.12s
# Step 2240/10000 (22%): TrainTime=00:04:41, Loss=1.3437, TokensPerSec=32606, AvgStepTime=0.12s
# Step 2250/10000 (22%): TrainTime=00:04:42, Loss=1.2912, TokensPerSec=32621, AvgStepTime=0.12s
# Step 2260/10000 (23%): TrainTime=00:04:43, Loss=1.3590, TokensPerSec=32635, AvgStepTime=0.12s
# Step 2270/10000 (23%): TrainTime=00:04:44, Loss=1.3231, TokensPerSec=32633, AvgStepTime=0.12s
# Step 2280/10000 (23%): TrainTime=00:04:46, Loss=1.3616, TokensPerSec=32594, AvgStepTime=0.12s
# Step 2290/10000 (23%): TrainTime=00:04:47, Loss=1.3696, TokensPerSec=32582, AvgStepTime=0.12s
# Step 2300/10000 (23%): TrainTime=00:04:49, Loss=1.3341, TokensPerSec=32596, AvgStepTime=0.12s
# Step 2310/10000 (23%): TrainTime=00:04:50, Loss=1.3288, TokensPerSec=32609, AvgStepTime=0.12s
# Step 2320/10000 (23%): TrainTime=00:04:51, Loss=1.2909, TokensPerSec=32616, AvgStepTime=0.12s
# Step 2330/10000 (23%): TrainTime=00:04:52, Loss=1.3439, TokensPerSec=32629, AvgStepTime=0.12s
# Step 2340/10000 (23%): TrainTime=00:04:53, Loss=1.3276, TokensPerSec=32640, AvgStepTime=0.12s
# Step 2350/10000 (24%): TrainTime=00:04:54, Loss=1.3122, TokensPerSec=32653, AvgStepTime=0.12s
# Step 2360/10000 (24%): TrainTime=00:04:55, Loss=1.3357, TokensPerSec=32664, AvgStepTime=0.12s
# Step 2370/10000 (24%): TrainTime=00:04:57, Loss=1.3606, TokensPerSec=32674, AvgStepTime=0.12s
# Step 2380/10000 (24%): TrainTime=00:04:58, Loss=1.3349, TokensPerSec=32644, AvgStepTime=0.12s
# Step 2390/10000 (24%): TrainTime=00:05:00, Loss=1.3592, TokensPerSec=32621, AvgStepTime=0.12s
# Step 2400/10000 (24%): TrainTime=00:05:01, Loss=1.3392, TokensPerSec=32635, AvgStepTime=0.12s
# Step 2410/10000 (24%): TrainTime=00:05:02, Loss=1.3345, TokensPerSec=32648, AvgStepTime=0.12s
# Step 2420/10000 (24%): TrainTime=00:05:03, Loss=1.3131, TokensPerSec=32662, AvgStepTime=0.12s
# Step 2430/10000 (24%): TrainTime=00:05:04, Loss=1.3183, TokensPerSec=32676, AvgStepTime=0.12s
# Step 2440/10000 (24%): TrainTime=00:05:05, Loss=1.3088, TokensPerSec=32689, AvgStepTime=0.12s
# Step 2450/10000 (24%): TrainTime=00:05:06, Loss=1.3031, TokensPerSec=32701, AvgStepTime=0.12s
# Step 2460/10000 (25%): TrainTime=00:05:07, Loss=1.3359, TokensPerSec=32716, AvgStepTime=0.12s
# Step 2470/10000 (25%): TrainTime=00:05:09, Loss=1.3261, TokensPerSec=32726, AvgStepTime=0.12s
# Step 2480/10000 (25%): TrainTime=00:05:10, Loss=1.3227, TokensPerSec=32715, AvgStepTime=0.12s
# Step 2490/10000 (25%): TrainTime=00:05:12, Loss=1.2723, TokensPerSec=32673, AvgStepTime=0.12s
# Step 2500/10000 (25%): TrainTime=00:05:13, Loss=1.3102, TokensPerSec=32687, AvgStepTime=0.12s
# Step 2510/10000 (25%): TrainTime=00:05:14, Loss=1.2897, TokensPerSec=32700, AvgStepTime=0.12s
# Step 2520/10000 (25%): TrainTime=00:05:15, Loss=1.3619, TokensPerSec=32712, AvgStepTime=0.12s
# Step 2530/10000 (25%): TrainTime=00:05:16, Loss=1.3147, TokensPerSec=32726, AvgStepTime=0.12s
# Step 2540/10000 (25%): TrainTime=00:05:17, Loss=1.3010, TokensPerSec=32738, AvgStepTime=0.12s
# Step 2550/10000 (26%): TrainTime=00:05:18, Loss=1.3069, TokensPerSec=32753, AvgStepTime=0.12s
# Step 2560/10000 (26%): TrainTime=00:05:20, Loss=1.3258, TokensPerSec=32763, AvgStepTime=0.12s
# Step 2570/10000 (26%): TrainTime=00:05:21, Loss=1.3172, TokensPerSec=32771, AvgStepTime=0.12s
# Step 2580/10000 (26%): TrainTime=00:05:22, Loss=1.2810, TokensPerSec=32766, AvgStepTime=0.12s
# Step 2590/10000 (26%): TrainTime=00:05:24, Loss=1.3542, TokensPerSec=32731, AvgStepTime=0.12s
# Step 2600/10000 (26%): TrainTime=00:05:25, Loss=1.2706, TokensPerSec=32725, AvgStepTime=0.12s
# Step 2610/10000 (26%): TrainTime=00:05:26, Loss=1.3588, TokensPerSec=32736, AvgStepTime=0.12s
# Step 2620/10000 (26%): TrainTime=00:05:27, Loss=1.2574, TokensPerSec=32745, AvgStepTime=0.12s
# Step 2630/10000 (26%): TrainTime=00:05:28, Loss=1.3384, TokensPerSec=32758, AvgStepTime=0.12s
# Step 2640/10000 (26%): TrainTime=00:05:29, Loss=1.3083, TokensPerSec=32770, AvgStepTime=0.12s
# Step 2650/10000 (26%): TrainTime=00:05:31, Loss=1.2889, TokensPerSec=32776, AvgStepTime=0.12s
# Step 2660/10000 (27%): TrainTime=00:05:32, Loss=1.2729, TokensPerSec=32786, AvgStepTime=0.12s
# Step 2670/10000 (27%): TrainTime=00:05:33, Loss=1.3270, TokensPerSec=32796, AvgStepTime=0.12s
# Step 2680/10000 (27%): TrainTime=00:05:34, Loss=1.2945, TokensPerSec=32803, AvgStepTime=0.12s
# Step 2690/10000 (27%): TrainTime=00:05:36, Loss=1.3466, TokensPerSec=32773, AvgStepTime=0.12s
# Step 2700/10000 (27%): TrainTime=00:05:37, Loss=1.2941, TokensPerSec=32754, AvgStepTime=0.12s
# Step 2710/10000 (27%): TrainTime=00:05:38, Loss=1.3288, TokensPerSec=32763, AvgStepTime=0.12s
# Step 2720/10000 (27%): TrainTime=00:05:39, Loss=1.2451, TokensPerSec=32769, AvgStepTime=0.12s
# Step 2730/10000 (27%): TrainTime=00:05:41, Loss=1.2951, TokensPerSec=32782, AvgStepTime=0.12s
# Step 2740/10000 (27%): TrainTime=00:05:42, Loss=1.2834, TokensPerSec=32793, AvgStepTime=0.12s
# Step 2750/10000 (28%): TrainTime=00:05:43, Loss=1.3432, TokensPerSec=32802, AvgStepTime=0.12s
# Step 2760/10000 (28%): TrainTime=00:05:44, Loss=1.3145, TokensPerSec=32815, AvgStepTime=0.12s
# Step 2770/10000 (28%): TrainTime=00:05:45, Loss=1.3119, TokensPerSec=32824, AvgStepTime=0.12s
# Step 2780/10000 (28%): TrainTime=00:05:46, Loss=1.2833, TokensPerSec=32831, AvgStepTime=0.12s
# Step 2790/10000 (28%): TrainTime=00:05:48, Loss=1.3066, TokensPerSec=32810, AvgStepTime=0.12s
# Step 2800/10000 (28%): TrainTime=00:05:49, Loss=1.2462, TokensPerSec=32780, AvgStepTime=0.12s
# Step 2810/10000 (28%): TrainTime=00:05:51, Loss=1.2535, TokensPerSec=32788, AvgStepTime=0.12s
# Step 2820/10000 (28%): TrainTime=00:05:52, Loss=1.3165, TokensPerSec=32799, AvgStepTime=0.12s
# Step 2830/10000 (28%): TrainTime=00:05:53, Loss=1.2492, TokensPerSec=32809, AvgStepTime=0.12s
# Step 2840/10000 (28%): TrainTime=00:05:54, Loss=1.2525, TokensPerSec=32820, AvgStepTime=0.12s
# Step 2850/10000 (28%): TrainTime=00:05:55, Loss=1.2818, TokensPerSec=32829, AvgStepTime=0.12s
# Step 2860/10000 (29%): TrainTime=00:05:56, Loss=1.2612, TokensPerSec=32839, AvgStepTime=0.12s
# Step 2870/10000 (29%): TrainTime=00:05:57, Loss=1.2851, TokensPerSec=32844, AvgStepTime=0.12s
# Step 2880/10000 (29%): TrainTime=00:05:59, Loss=1.2882, TokensPerSec=32854, AvgStepTime=0.12s
# Step 2890/10000 (29%): TrainTime=00:06:00, Loss=1.3029, TokensPerSec=32842, AvgStepTime=0.12s
# Step 2900/10000 (29%): TrainTime=00:06:02, Loss=1.2804, TokensPerSec=32806, AvgStepTime=0.12s
# Step 2910/10000 (29%): TrainTime=00:06:03, Loss=1.2661, TokensPerSec=32813, AvgStepTime=0.12s
# Step 2920/10000 (29%): TrainTime=00:06:04, Loss=1.2845, TokensPerSec=32823, AvgStepTime=0.12s
# Step 2930/10000 (29%): TrainTime=00:06:05, Loss=1.2514, TokensPerSec=32829, AvgStepTime=0.12s
# Step 2940/10000 (29%): TrainTime=00:06:06, Loss=1.2632, TokensPerSec=32836, AvgStepTime=0.12s
# Step 2950/10000 (30%): TrainTime=00:06:07, Loss=1.2224, TokensPerSec=32847, AvgStepTime=0.12s
# Step 2960/10000 (30%): TrainTime=00:06:09, Loss=1.2744, TokensPerSec=32856, AvgStepTime=0.12s
# Step 2970/10000 (30%): TrainTime=00:06:10, Loss=1.3233, TokensPerSec=32861, AvgStepTime=0.12s
# Step 2980/10000 (30%): TrainTime=00:06:11, Loss=1.2594, TokensPerSec=32869, AvgStepTime=0.12s
# Step 2990/10000 (30%): TrainTime=00:06:12, Loss=1.3116, TokensPerSec=32869, AvgStepTime=0.12s
# Step 3000/10000 (30%): TrainTime=00:06:14, Loss=1.2941, TokensPerSec=32839, AvgStepTime=0.12s
# Step 3010/10000 (30%): TrainTime=00:06:15, Loss=1.2417, TokensPerSec=32835, AvgStepTime=0.12s
# Step 3020/10000 (30%): TrainTime=00:06:16, Loss=1.2841, TokensPerSec=32845, AvgStepTime=0.12s
# Step 3030/10000 (30%): TrainTime=00:06:17, Loss=1.2968, TokensPerSec=32852, AvgStepTime=0.12s
# Step 3040/10000 (30%): TrainTime=00:06:18, Loss=1.2678, TokensPerSec=32858, AvgStepTime=0.12s
# Step 3050/10000 (30%): TrainTime=00:06:20, Loss=1.2485, TokensPerSec=32867, AvgStepTime=0.12s
# Step 3060/10000 (31%): TrainTime=00:06:21, Loss=1.2647, TokensPerSec=32877, AvgStepTime=0.12s
# Step 3070/10000 (31%): TrainTime=00:06:22, Loss=1.2550, TokensPerSec=32886, AvgStepTime=0.12s
# Step 3080/10000 (31%): TrainTime=00:06:23, Loss=1.2558, TokensPerSec=32896, AvgStepTime=0.12s
# Step 3090/10000 (31%): TrainTime=00:06:24, Loss=1.2943, TokensPerSec=32902, AvgStepTime=0.12s
# Step 3100/10000 (31%): TrainTime=00:06:26, Loss=1.2474, TokensPerSec=32877, AvgStepTime=0.12s
# Step 3110/10000 (31%): TrainTime=00:06:27, Loss=1.2493, TokensPerSec=32862, AvgStepTime=0.12s
# Step 3120/10000 (31%): TrainTime=00:06:28, Loss=1.2299, TokensPerSec=32869, AvgStepTime=0.12s
# Step 3130/10000 (31%): TrainTime=00:06:29, Loss=1.2737, TokensPerSec=32876, AvgStepTime=0.12s
# Step 3140/10000 (31%): TrainTime=00:06:31, Loss=1.2459, TokensPerSec=32885, AvgStepTime=0.12s
# Step 3150/10000 (32%): TrainTime=00:06:32, Loss=1.2702, TokensPerSec=32894, AvgStepTime=0.12s
# Step 3160/10000 (32%): TrainTime=00:06:33, Loss=1.2658, TokensPerSec=32905, AvgStepTime=0.12s
# Step 3170/10000 (32%): TrainTime=00:06:34, Loss=1.2675, TokensPerSec=32913, AvgStepTime=0.12s
# Step 3180/10000 (32%): TrainTime=00:06:35, Loss=1.2868, TokensPerSec=32922, AvgStepTime=0.12s
# Step 3190/10000 (32%): TrainTime=00:06:36, Loss=1.2519, TokensPerSec=32927, AvgStepTime=0.12s
# Step 3200/10000 (32%): TrainTime=00:06:38, Loss=1.2570, TokensPerSec=32910, AvgStepTime=0.12s
# Step 3210/10000 (32%): TrainTime=00:06:39, Loss=1.2298, TokensPerSec=32877, AvgStepTime=0.12s
# Step 3220/10000 (32%): TrainTime=00:06:41, Loss=1.3052, TokensPerSec=32884, AvgStepTime=0.12s
# Step 3230/10000 (32%): TrainTime=00:06:42, Loss=1.2438, TokensPerSec=32893, AvgStepTime=0.12s
# Step 3240/10000 (32%): TrainTime=00:06:43, Loss=1.2806, TokensPerSec=32901, AvgStepTime=0.12s
# Step 3250/10000 (32%): TrainTime=00:06:44, Loss=1.2296, TokensPerSec=32910, AvgStepTime=0.12s
# Step 3260/10000 (33%): TrainTime=00:06:45, Loss=1.2949, TokensPerSec=32917, AvgStepTime=0.12s
# Step 3270/10000 (33%): TrainTime=00:06:46, Loss=1.2344, TokensPerSec=32925, AvgStepTime=0.12s
# Step 3280/10000 (33%): TrainTime=00:06:47, Loss=1.2694, TokensPerSec=32933, AvgStepTime=0.12s
# Step 3290/10000 (33%): TrainTime=00:06:49, Loss=1.2301, TokensPerSec=32944, AvgStepTime=0.12s
# Step 3300/10000 (33%): TrainTime=00:06:50, Loss=1.2693, TokensPerSec=32938, AvgStepTime=0.12s
# Step 3310/10000 (33%): TrainTime=00:06:51, Loss=1.2792, TokensPerSec=32910, AvgStepTime=0.12s
# Step 3320/10000 (33%): TrainTime=00:06:53, Loss=1.3388, TokensPerSec=32910, AvgStepTime=0.12s
# Step 3330/10000 (33%): TrainTime=00:06:54, Loss=1.2437, TokensPerSec=32919, AvgStepTime=0.12s
# Step 3340/10000 (33%): TrainTime=00:06:55, Loss=1.2588, TokensPerSec=32925, AvgStepTime=0.12s
# Step 3350/10000 (34%): TrainTime=00:06:56, Loss=1.2451, TokensPerSec=32934, AvgStepTime=0.12s
# Step 3360/10000 (34%): TrainTime=00:06:57, Loss=1.2890, TokensPerSec=32943, AvgStepTime=0.12s
# Step 3370/10000 (34%): TrainTime=00:06:58, Loss=1.2471, TokensPerSec=32952, AvgStepTime=0.12s
# Step 3380/10000 (34%): TrainTime=00:07:00, Loss=1.2532, TokensPerSec=32961, AvgStepTime=0.12s
# Step 3390/10000 (34%): TrainTime=00:07:01, Loss=1.2592, TokensPerSec=32969, AvgStepTime=0.12s
# Step 3400/10000 (34%): TrainTime=00:07:02, Loss=1.2409, TokensPerSec=32972, AvgStepTime=0.12s
# Step 3410/10000 (34%): TrainTime=00:07:03, Loss=1.2624, TokensPerSec=32947, AvgStepTime=0.12s
# Step 3420/10000 (34%): TrainTime=00:07:05, Loss=1.2673, TokensPerSec=32936, AvgStepTime=0.12s
# Step 3430/10000 (34%): TrainTime=00:07:06, Loss=1.2197, TokensPerSec=32940, AvgStepTime=0.12s
# Step 3440/10000 (34%): TrainTime=00:07:07, Loss=1.2770, TokensPerSec=32947, AvgStepTime=0.12s
# Step 3450/10000 (34%): TrainTime=00:07:08, Loss=1.2765, TokensPerSec=32954, AvgStepTime=0.12s
# Step 3460/10000 (35%): TrainTime=00:07:10, Loss=1.2502, TokensPerSec=32956, AvgStepTime=0.12s
# Step 3470/10000 (35%): TrainTime=00:07:11, Loss=1.2747, TokensPerSec=32959, AvgStepTime=0.12s
# Step 3480/10000 (35%): TrainTime=00:07:12, Loss=1.2786, TokensPerSec=32964, AvgStepTime=0.12s
# Step 3490/10000 (35%): TrainTime=00:07:13, Loss=1.2564, TokensPerSec=32973, AvgStepTime=0.12s
# Step 3500/10000 (35%): TrainTime=00:07:14, Loss=1.2630, TokensPerSec=32982, AvgStepTime=0.12s
# Step 3510/10000 (35%): TrainTime=00:07:16, Loss=1.2722, TokensPerSec=32957, AvgStepTime=0.12s
# Step 3520/10000 (35%): TrainTime=00:07:17, Loss=1.2989, TokensPerSec=32941, AvgStepTime=0.12s
# Step 3530/10000 (35%): TrainTime=00:07:18, Loss=1.2520, TokensPerSec=32946, AvgStepTime=0.12s
# Step 3540/10000 (35%): TrainTime=00:07:20, Loss=1.2643, TokensPerSec=32954, AvgStepTime=0.12s
# Step 3550/10000 (36%): TrainTime=00:07:21, Loss=1.2500, TokensPerSec=32962, AvgStepTime=0.12s
# Step 3560/10000 (36%): TrainTime=00:07:22, Loss=1.2441, TokensPerSec=32972, AvgStepTime=0.12s
# Step 3570/10000 (36%): TrainTime=00:07:23, Loss=1.2336, TokensPerSec=32979, AvgStepTime=0.12s
# Step 3580/10000 (36%): TrainTime=00:07:24, Loss=1.2252, TokensPerSec=32986, AvgStepTime=0.12s
# Step 3590/10000 (36%): TrainTime=00:07:25, Loss=1.3248, TokensPerSec=32995, AvgStepTime=0.12s
# Step 3600/10000 (36%): TrainTime=00:07:26, Loss=1.2610, TokensPerSec=33003, AvgStepTime=0.12s
# Step 3610/10000 (36%): TrainTime=00:07:28, Loss=1.2265, TokensPerSec=32992, AvgStepTime=0.12s
# Step 3620/10000 (36%): TrainTime=00:07:29, Loss=1.2490, TokensPerSec=32965, AvgStepTime=0.12s
# Step 3630/10000 (36%): TrainTime=00:07:30, Loss=1.2303, TokensPerSec=32973, AvgStepTime=0.12s
# Step 3640/10000 (36%): TrainTime=00:07:32, Loss=1.2560, TokensPerSec=32981, AvgStepTime=0.12s
# Step 3650/10000 (36%): TrainTime=00:07:33, Loss=1.2382, TokensPerSec=32991, AvgStepTime=0.12s
# Step 3660/10000 (37%): TrainTime=00:07:34, Loss=1.2470, TokensPerSec=32999, AvgStepTime=0.12s
# Step 3670/10000 (37%): TrainTime=00:07:35, Loss=1.2267, TokensPerSec=33007, AvgStepTime=0.12s
# Step 3680/10000 (37%): TrainTime=00:07:36, Loss=1.2811, TokensPerSec=33014, AvgStepTime=0.12s
# Step 3690/10000 (37%): TrainTime=00:07:37, Loss=1.2382, TokensPerSec=33021, AvgStepTime=0.12s
# Step 3700/10000 (37%): TrainTime=00:07:38, Loss=1.2792, TokensPerSec=33028, AvgStepTime=0.12s
# Step 3710/10000 (37%): TrainTime=00:07:40, Loss=1.2187, TokensPerSec=33026, AvgStepTime=0.12s
# Step 3720/10000 (37%): TrainTime=00:07:41, Loss=1.2185, TokensPerSec=32994, AvgStepTime=0.12s
# Step 3730/10000 (37%): TrainTime=00:07:43, Loss=1.2256, TokensPerSec=32992, AvgStepTime=0.12s
# Step 3740/10000 (37%): TrainTime=00:07:44, Loss=1.2315, TokensPerSec=33000, AvgStepTime=0.12s
# Step 3750/10000 (38%): TrainTime=00:07:45, Loss=1.2215, TokensPerSec=33007, AvgStepTime=0.12s
# Step 3760/10000 (38%): TrainTime=00:07:46, Loss=1.2010, TokensPerSec=33012, AvgStepTime=0.12s
# Step 3770/10000 (38%): TrainTime=00:07:47, Loss=1.2595, TokensPerSec=33018, AvgStepTime=0.12s
# Step 3780/10000 (38%): TrainTime=00:07:48, Loss=1.2227, TokensPerSec=33022, AvgStepTime=0.12s
# Step 3790/10000 (38%): TrainTime=00:07:50, Loss=1.2390, TokensPerSec=33029, AvgStepTime=0.12s
# Step 3800/10000 (38%): TrainTime=00:07:51, Loss=1.2486, TokensPerSec=33034, AvgStepTime=0.12s
# Step 3810/10000 (38%): TrainTime=00:07:52, Loss=1.2435, TokensPerSec=33035, AvgStepTime=0.12s
# Step 3820/10000 (38%): TrainTime=00:07:53, Loss=1.2712, TokensPerSec=33012, AvgStepTime=0.12s
# Step 3830/10000 (38%): TrainTime=00:07:55, Loss=1.2330, TokensPerSec=33006, AvgStepTime=0.12s
# Step 3840/10000 (38%): TrainTime=00:07:56, Loss=1.2158, TokensPerSec=33014, AvgStepTime=0.12s
# Step 3850/10000 (38%): TrainTime=00:07:57, Loss=1.2342, TokensPerSec=33021, AvgStepTime=0.12s
# Step 3860/10000 (39%): TrainTime=00:07:58, Loss=1.2143, TokensPerSec=33029, AvgStepTime=0.12s
# Step 3870/10000 (39%): TrainTime=00:07:59, Loss=1.2584, TokensPerSec=33037, AvgStepTime=0.12s
# Step 3880/10000 (39%): TrainTime=00:08:00, Loss=1.2036, TokensPerSec=33044, AvgStepTime=0.12s
# Step 3890/10000 (39%): TrainTime=00:08:02, Loss=1.2342, TokensPerSec=33052, AvgStepTime=0.12s
# Step 3900/10000 (39%): TrainTime=00:08:03, Loss=1.2137, TokensPerSec=33057, AvgStepTime=0.12s
# Step 3910/10000 (39%): TrainTime=00:08:04, Loss=1.2563, TokensPerSec=33063, AvgStepTime=0.12s
# Step 3920/10000 (39%): TrainTime=00:08:05, Loss=1.1610, TokensPerSec=33049, AvgStepTime=0.12s
# Step 3930/10000 (39%): TrainTime=00:08:07, Loss=1.1933, TokensPerSec=33028, AvgStepTime=0.12s
# Step 3940/10000 (39%): TrainTime=00:08:08, Loss=1.2867, TokensPerSec=33033, AvgStepTime=0.12s
# Step 3950/10000 (40%): TrainTime=00:08:09, Loss=1.2214, TokensPerSec=33038, AvgStepTime=0.12s
# Step 3960/10000 (40%): TrainTime=00:08:10, Loss=1.2906, TokensPerSec=33043, AvgStepTime=0.12s
# Step 3970/10000 (40%): TrainTime=00:08:12, Loss=1.1953, TokensPerSec=33048, AvgStepTime=0.12s
# Step 3980/10000 (40%): TrainTime=00:08:13, Loss=1.2693, TokensPerSec=33054, AvgStepTime=0.12s
# Step 3990/10000 (40%): TrainTime=00:08:14, Loss=1.2230, TokensPerSec=33061, AvgStepTime=0.12s
# Step 4000/10000 (40%): TrainTime=00:08:15, Loss=1.2234, TokensPerSec=33067, AvgStepTime=0.12s
# Step 4010/10000 (40%): TrainTime=00:08:16, Loss=1.1778, TokensPerSec=33073, AvgStepTime=0.12s
# Step 4020/10000 (40%): TrainTime=00:08:18, Loss=1.2305, TokensPerSec=33060, AvgStepTime=0.12s
# Step 4030/10000 (40%): TrainTime=00:08:19, Loss=1.1737, TokensPerSec=33036, AvgStepTime=0.12s
# Step 4040/10000 (40%): TrainTime=00:08:20, Loss=1.2295, TokensPerSec=33042, AvgStepTime=0.12s
# Step 4050/10000 (40%): TrainTime=00:08:21, Loss=1.2022, TokensPerSec=33049, AvgStepTime=0.12s
# Step 4060/10000 (41%): TrainTime=00:08:23, Loss=1.1812, TokensPerSec=33056, AvgStepTime=0.12s
# Step 4070/10000 (41%): TrainTime=00:08:24, Loss=1.2080, TokensPerSec=33062, AvgStepTime=0.12s
# Step 4080/10000 (41%): TrainTime=00:08:25, Loss=1.2481, TokensPerSec=33068, AvgStepTime=0.12s
# Step 4090/10000 (41%): TrainTime=00:08:26, Loss=1.2118, TokensPerSec=33074, AvgStepTime=0.12s
# Step 4100/10000 (41%): TrainTime=00:08:27, Loss=1.1722, TokensPerSec=33080, AvgStepTime=0.12s
# Step 4110/10000 (41%): TrainTime=00:08:28, Loss=1.1756, TokensPerSec=33085, AvgStepTime=0.12s
# Step 4120/10000 (41%): TrainTime=00:08:30, Loss=1.2238, TokensPerSec=33079, AvgStepTime=0.12s
# Step 4130/10000 (41%): TrainTime=00:08:31, Loss=1.2243, TokensPerSec=33055, AvgStepTime=0.12s
# Step 4140/10000 (41%): TrainTime=00:08:33, Loss=1.1914, TokensPerSec=33053, AvgStepTime=0.12s
# Step 4150/10000 (42%): TrainTime=00:08:34, Loss=1.2033, TokensPerSec=33059, AvgStepTime=0.12s
# Step 4160/10000 (42%): TrainTime=00:08:35, Loss=1.1808, TokensPerSec=33064, AvgStepTime=0.12s
# Step 4170/10000 (42%): TrainTime=00:08:36, Loss=1.2421, TokensPerSec=33071, AvgStepTime=0.12s
# Step 4180/10000 (42%): TrainTime=00:08:37, Loss=1.2308, TokensPerSec=33076, AvgStepTime=0.12s
# Step 4190/10000 (42%): TrainTime=00:08:38, Loss=1.1973, TokensPerSec=33081, AvgStepTime=0.12s
# Step 4200/10000 (42%): TrainTime=00:08:39, Loss=1.2319, TokensPerSec=33086, AvgStepTime=0.12s
# Step 4210/10000 (42%): TrainTime=00:08:41, Loss=1.2015, TokensPerSec=33089, AvgStepTime=0.12s
# Step 4220/10000 (42%): TrainTime=00:08:42, Loss=1.2545, TokensPerSec=33086, AvgStepTime=0.12s
# Step 4230/10000 (42%): TrainTime=00:08:43, Loss=1.2093, TokensPerSec=33067, AvgStepTime=0.12s
# Step 4240/10000 (42%): TrainTime=00:08:45, Loss=1.2246, TokensPerSec=33060, AvgStepTime=0.12s
# Step 4250/10000 (42%): TrainTime=00:08:46, Loss=1.2084, TokensPerSec=33066, AvgStepTime=0.12s
# Step 4260/10000 (43%): TrainTime=00:08:47, Loss=1.2343, TokensPerSec=33071, AvgStepTime=0.12s
# Step 4270/10000 (43%): TrainTime=00:08:48, Loss=1.2528, TokensPerSec=33074, AvgStepTime=0.12s
# Step 4280/10000 (43%): TrainTime=00:08:49, Loss=1.1496, TokensPerSec=33080, AvgStepTime=0.12s
# Step 4290/10000 (43%): TrainTime=00:08:51, Loss=1.2255, TokensPerSec=33084, AvgStepTime=0.12s
# Step 4300/10000 (43%): TrainTime=00:08:52, Loss=1.2013, TokensPerSec=33091, AvgStepTime=0.12s
# Step 4310/10000 (43%): TrainTime=00:08:53, Loss=1.2119, TokensPerSec=33097, AvgStepTime=0.12s
# Step 4320/10000 (43%): TrainTime=00:08:54, Loss=1.1843, TokensPerSec=33103, AvgStepTime=0.12s
# Step 4330/10000 (43%): TrainTime=00:08:56, Loss=1.2226, TokensPerSec=33082, AvgStepTime=0.12s
# Step 4340/10000 (43%): TrainTime=00:08:57, Loss=1.2122, TokensPerSec=33068, AvgStepTime=0.12s
# Step 4350/10000 (44%): TrainTime=00:08:58, Loss=1.2274, TokensPerSec=33074, AvgStepTime=0.12s
# Step 4360/10000 (44%): TrainTime=00:08:59, Loss=1.1896, TokensPerSec=33079, AvgStepTime=0.12s
# Step 4370/10000 (44%): TrainTime=00:09:01, Loss=1.1665, TokensPerSec=33082, AvgStepTime=0.12s
# Step 4380/10000 (44%): TrainTime=00:09:02, Loss=1.1725, TokensPerSec=33086, AvgStepTime=0.12s
# Step 4390/10000 (44%): TrainTime=00:09:03, Loss=1.1844, TokensPerSec=33091, AvgStepTime=0.12s
# Step 4400/10000 (44%): TrainTime=00:09:04, Loss=1.2018, TokensPerSec=33097, AvgStepTime=0.12s
# Step 4410/10000 (44%): TrainTime=00:09:05, Loss=1.2000, TokensPerSec=33103, AvgStepTime=0.12s
# Step 4420/10000 (44%): TrainTime=00:09:06, Loss=1.1989, TokensPerSec=33108, AvgStepTime=0.12s
# Step 4430/10000 (44%): TrainTime=00:09:08, Loss=1.2108, TokensPerSec=33095, AvgStepTime=0.12s
# Step 4440/10000 (44%): TrainTime=00:09:09, Loss=1.1848, TokensPerSec=33075, AvgStepTime=0.12s
# Step 4450/10000 (44%): TrainTime=00:09:11, Loss=1.1548, TokensPerSec=33079, AvgStepTime=0.12s
# Step 4460/10000 (45%): TrainTime=00:09:12, Loss=1.1815, TokensPerSec=33083, AvgStepTime=0.12s
# Step 4470/10000 (45%): TrainTime=00:09:13, Loss=1.2053, TokensPerSec=33087, AvgStepTime=0.12s
# Step 4480/10000 (45%): TrainTime=00:09:14, Loss=1.1861, TokensPerSec=33090, AvgStepTime=0.12s
# Step 4490/10000 (45%): TrainTime=00:09:15, Loss=1.1972, TokensPerSec=33095, AvgStepTime=0.12s
# Step 4500/10000 (45%): TrainTime=00:09:16, Loss=1.1847, TokensPerSec=33101, AvgStepTime=0.12s
# Step 4510/10000 (45%): TrainTime=00:09:17, Loss=1.1840, TokensPerSec=33106, AvgStepTime=0.12s
# Step 4520/10000 (45%): TrainTime=00:09:19, Loss=1.2203, TokensPerSec=33111, AvgStepTime=0.12s
# Step 4530/10000 (45%): TrainTime=00:09:20, Loss=1.1736, TokensPerSec=33101, AvgStepTime=0.12s
# Step 4540/10000 (45%): TrainTime=00:09:22, Loss=1.2106, TokensPerSec=33079, AvgStepTime=0.12s
# Step 4550/10000 (46%): TrainTime=00:09:23, Loss=1.1629, TokensPerSec=33082, AvgStepTime=0.12s
# Step 4560/10000 (46%): TrainTime=00:09:24, Loss=1.1994, TokensPerSec=33086, AvgStepTime=0.12s
# Step 4570/10000 (46%): TrainTime=00:09:25, Loss=1.1693, TokensPerSec=33089, AvgStepTime=0.12s
# Step 4580/10000 (46%): TrainTime=00:09:26, Loss=1.1506, TokensPerSec=33092, AvgStepTime=0.12s
# Step 4590/10000 (46%): TrainTime=00:09:28, Loss=1.1460, TokensPerSec=33097, AvgStepTime=0.12s
# Step 4600/10000 (46%): TrainTime=00:09:29, Loss=1.1560, TokensPerSec=33103, AvgStepTime=0.12s
# Step 4610/10000 (46%): TrainTime=00:09:30, Loss=1.1916, TokensPerSec=33109, AvgStepTime=0.12s
# Step 4620/10000 (46%): TrainTime=00:09:31, Loss=1.2000, TokensPerSec=33115, AvgStepTime=0.12s
# Step 4630/10000 (46%): TrainTime=00:09:32, Loss=1.1842, TokensPerSec=33109, AvgStepTime=0.12s
# Step 4640/10000 (46%): TrainTime=00:09:34, Loss=1.2056, TokensPerSec=33085, AvgStepTime=0.12s
# Step 4650/10000 (46%): TrainTime=00:09:35, Loss=1.2183, TokensPerSec=33089, AvgStepTime=0.12s
# Step 4660/10000 (47%): TrainTime=00:09:36, Loss=1.1631, TokensPerSec=33094, AvgStepTime=0.12s
# Step 4670/10000 (47%): TrainTime=00:09:37, Loss=1.1986, TokensPerSec=33097, AvgStepTime=0.12s
# Step 4680/10000 (47%): TrainTime=00:09:39, Loss=1.1565, TokensPerSec=33101, AvgStepTime=0.12s
# Step 4690/10000 (47%): TrainTime=00:09:40, Loss=1.1989, TokensPerSec=33108, AvgStepTime=0.12s
# Step 4700/10000 (47%): TrainTime=00:09:41, Loss=1.1476, TokensPerSec=33112, AvgStepTime=0.12s
# Step 4710/10000 (47%): TrainTime=00:09:42, Loss=1.1869, TokensPerSec=33115, AvgStepTime=0.12s
# Step 4720/10000 (47%): TrainTime=00:09:43, Loss=1.1944, TokensPerSec=33120, AvgStepTime=0.12s
# Step 4730/10000 (47%): TrainTime=00:09:45, Loss=1.1707, TokensPerSec=33115, AvgStepTime=0.12s
# Step 4740/10000 (47%): TrainTime=00:09:46, Loss=1.1634, TokensPerSec=33092, AvgStepTime=0.12s
# Step 4750/10000 (48%): TrainTime=00:09:47, Loss=1.1726, TokensPerSec=33090, AvgStepTime=0.12s
# Step 4760/10000 (48%): TrainTime=00:09:49, Loss=1.2005, TokensPerSec=33094, AvgStepTime=0.12s
# Step 4770/10000 (48%): TrainTime=00:09:50, Loss=1.1914, TokensPerSec=33097, AvgStepTime=0.12s
# Step 4780/10000 (48%): TrainTime=00:09:51, Loss=1.1974, TokensPerSec=33100, AvgStepTime=0.12s
# Step 4790/10000 (48%): TrainTime=00:09:52, Loss=1.1877, TokensPerSec=33100, AvgStepTime=0.12s
# Step 4800/10000 (48%): TrainTime=00:09:53, Loss=1.1739, TokensPerSec=33102, AvgStepTime=0.12s
# Step 4810/10000 (48%): TrainTime=00:09:55, Loss=1.2081, TokensPerSec=33105, AvgStepTime=0.12s
# Step 4820/10000 (48%): TrainTime=00:09:56, Loss=1.1800, TokensPerSec=33109, AvgStepTime=0.12s
# Step 4830/10000 (48%): TrainTime=00:09:57, Loss=1.2123, TokensPerSec=33103, AvgStepTime=0.12s
# Step 4840/10000 (48%): TrainTime=00:09:59, Loss=1.1405, TokensPerSec=33082, AvgStepTime=0.12s
# Step 4850/10000 (48%): TrainTime=00:10:00, Loss=1.1509, TokensPerSec=33083, AvgStepTime=0.12s
# Step 4860/10000 (49%): TrainTime=00:10:01, Loss=1.1989, TokensPerSec=33085, AvgStepTime=0.12s
# Step 4870/10000 (49%): TrainTime=00:10:02, Loss=1.1809, TokensPerSec=33088, AvgStepTime=0.12s
# Step 4880/10000 (49%): TrainTime=00:10:03, Loss=1.1285, TokensPerSec=33094, AvgStepTime=0.12s
# Step 4890/10000 (49%): TrainTime=00:10:05, Loss=1.1802, TokensPerSec=33097, AvgStepTime=0.12s
# Step 4900/10000 (49%): TrainTime=00:10:06, Loss=1.1889, TokensPerSec=33103, AvgStepTime=0.12s
# Step 4910/10000 (49%): TrainTime=00:10:07, Loss=1.1486, TokensPerSec=33108, AvgStepTime=0.12s
# Step 4920/10000 (49%): TrainTime=00:10:08, Loss=1.1607, TokensPerSec=33112, AvgStepTime=0.12s
# Step 4930/10000 (49%): TrainTime=00:10:09, Loss=1.2091, TokensPerSec=33109, AvgStepTime=0.12s
# Step 4940/10000 (49%): TrainTime=00:10:11, Loss=1.1414, TokensPerSec=33089, AvgStepTime=0.12s
# Step 4950/10000 (50%): TrainTime=00:10:12, Loss=1.1631, TokensPerSec=33084, AvgStepTime=0.12s
# Step 4960/10000 (50%): TrainTime=00:10:13, Loss=1.1282, TokensPerSec=33090, AvgStepTime=0.12s
# Step 4970/10000 (50%): TrainTime=00:10:15, Loss=1.1584, TokensPerSec=33095, AvgStepTime=0.12s
# Step 4980/10000 (50%): TrainTime=00:10:16, Loss=1.0781, TokensPerSec=33099, AvgStepTime=0.12s
# Step 4990/10000 (50%): TrainTime=00:10:17, Loss=1.1503, TokensPerSec=33105, AvgStepTime=0.12s
# Step 5000/10000 (50%): TrainTime=00:10:18, Loss=1.1730, TokensPerSec=33110, AvgStepTime=0.12s
# Step 5010/10000 (50%): TrainTime=00:10:19, Loss=1.1723, TokensPerSec=33116, AvgStepTime=0.12s
# Step 5020/10000 (50%): TrainTime=00:10:20, Loss=1.1455, TokensPerSec=33123, AvgStepTime=0.12s
# Step 5030/10000 (50%): TrainTime=00:10:21, Loss=1.1870, TokensPerSec=33127, AvgStepTime=0.12s
# Step 5040/10000 (50%): TrainTime=00:10:23, Loss=1.0962, TokensPerSec=33111, AvgStepTime=0.12s
# Step 5050/10000 (50%): TrainTime=00:10:24, Loss=1.1879, TokensPerSec=33099, AvgStepTime=0.12s
# Step 5060/10000 (51%): TrainTime=00:10:26, Loss=1.1428, TokensPerSec=33105, AvgStepTime=0.12s
# Step 5070/10000 (51%): TrainTime=00:10:27, Loss=1.1397, TokensPerSec=33109, AvgStepTime=0.12s
# Step 5080/10000 (51%): TrainTime=00:10:28, Loss=1.1428, TokensPerSec=33112, AvgStepTime=0.12s
# Step 5090/10000 (51%): TrainTime=00:10:29, Loss=1.1503, TokensPerSec=33118, AvgStepTime=0.12s
# Step 5100/10000 (51%): TrainTime=00:10:30, Loss=1.1717, TokensPerSec=33123, AvgStepTime=0.12s
# Step 5110/10000 (51%): TrainTime=00:10:31, Loss=1.1683, TokensPerSec=33129, AvgStepTime=0.12s
# Step 5120/10000 (51%): TrainTime=00:10:32, Loss=1.1856, TokensPerSec=33134, AvgStepTime=0.12s
# ...
# Step 8310/10000 (83%): TrainTime=00:17:03, Loss=0.9606, TokensPerSec=33261, AvgStepTime=0.12s
# Step 8320/10000 (83%): TrainTime=00:17:04, Loss=0.9900, TokensPerSec=33263, AvgStepTime=0.12s
# Step 8330/10000 (83%): TrainTime=00:17:05, Loss=0.9899, TokensPerSec=33265, AvgStepTime=0.12s
# Step 8340/10000 (83%): TrainTime=00:17:06, Loss=0.9733, TokensPerSec=33267, AvgStepTime=0.12s
# Step 8350/10000 (84%): TrainTime=00:17:08, Loss=1.0116, TokensPerSec=33269, AvgStepTime=0.12s
# Step 8360/10000 (84%): TrainTime=00:17:09, Loss=0.9925, TokensPerSec=33271, AvgStepTime=0.12s
# Step 8370/10000 (84%): TrainTime=00:17:10, Loss=0.9676, TokensPerSec=33263, AvgStepTime=0.12s
# Step 8380/10000 (84%): TrainTime=00:17:12, Loss=0.9587, TokensPerSec=33255, AvgStepTime=0.12s
# Step 8390/10000 (84%): TrainTime=00:17:13, Loss=0.9719, TokensPerSec=33256, AvgStepTime=0.12s
# Step 8400/10000 (84%): TrainTime=00:17:14, Loss=1.0337, TokensPerSec=33259, AvgStepTime=0.12s
# Step 8410/10000 (84%): TrainTime=00:17:15, Loss=0.9514, TokensPerSec=33260, AvgStepTime=0.12s
# Step 8420/10000 (84%): TrainTime=00:17:16, Loss=0.9978, TokensPerSec=33261, AvgStepTime=0.12s
# Step 8430/10000 (84%): TrainTime=00:17:18, Loss=0.9441, TokensPerSec=33263, AvgStepTime=0.12s
# Step 8440/10000 (84%): TrainTime=00:17:19, Loss=0.9473, TokensPerSec=33266, AvgStepTime=0.12s
# Step 8450/10000 (84%): TrainTime=00:17:20, Loss=0.9376, TokensPerSec=33268, AvgStepTime=0.12s
# Step 8460/10000 (85%): TrainTime=00:17:21, Loss=0.9534, TokensPerSec=33270, AvgStepTime=0.12s
# Step 8470/10000 (85%): TrainTime=00:17:23, Loss=0.9324, TokensPerSec=33262, AvgStepTime=0.12s
# Step 8480/10000 (85%): TrainTime=00:17:24, Loss=0.9916, TokensPerSec=33255, AvgStepTime=0.12s
# Step 8490/10000 (85%): TrainTime=00:17:25, Loss=0.9572, TokensPerSec=33257, AvgStepTime=0.12s
# Step 8500/10000 (85%): TrainTime=00:17:26, Loss=0.9474, TokensPerSec=33259, AvgStepTime=0.12s
# Step 8510/10000 (85%): TrainTime=00:17:27, Loss=0.9584, TokensPerSec=33261, AvgStepTime=0.12s
# Step 8520/10000 (85%): TrainTime=00:17:29, Loss=0.9335, TokensPerSec=33264, AvgStepTime=0.12s
# Step 8530/10000 (85%): TrainTime=00:17:30, Loss=0.9863, TokensPerSec=33267, AvgStepTime=0.12s
# Step 8540/10000 (85%): TrainTime=00:17:31, Loss=0.9696, TokensPerSec=33269, AvgStepTime=0.12s
# Step 8550/10000 (86%): TrainTime=00:17:32, Loss=0.9914, TokensPerSec=33272, AvgStepTime=0.12s
# Step 8560/10000 (86%): TrainTime=00:17:33, Loss=1.0076, TokensPerSec=33274, AvgStepTime=0.12s
# Step 8570/10000 (86%): TrainTime=00:17:35, Loss=0.9884, TokensPerSec=33267, AvgStepTime=0.12s
# Step 8580/10000 (86%): TrainTime=00:17:36, Loss=0.9428, TokensPerSec=33259, AvgStepTime=0.12s
# Step 8590/10000 (86%): TrainTime=00:17:37, Loss=1.0023, TokensPerSec=33261, AvgStepTime=0.12s
# Step 8600/10000 (86%): TrainTime=00:17:38, Loss=1.0073, TokensPerSec=33264, AvgStepTime=0.12s
# Step 8610/10000 (86%): TrainTime=00:17:40, Loss=0.9540, TokensPerSec=33266, AvgStepTime=0.12s
# Step 8620/10000 (86%): TrainTime=00:17:41, Loss=0.9513, TokensPerSec=33268, AvgStepTime=0.12s
# Step 8630/10000 (86%): TrainTime=00:17:42, Loss=0.9329, TokensPerSec=33270, AvgStepTime=0.12s
# Step 8640/10000 (86%): TrainTime=00:17:43, Loss=0.9306, TokensPerSec=33271, AvgStepTime=0.12s
# Step 8650/10000 (86%): TrainTime=00:17:44, Loss=0.9480, TokensPerSec=33274, AvgStepTime=0.12s
# Step 8660/10000 (87%): TrainTime=00:17:45, Loss=0.9394, TokensPerSec=33276, AvgStepTime=0.12s
# Step 8670/10000 (87%): TrainTime=00:17:47, Loss=0.9166, TokensPerSec=33267, AvgStepTime=0.12s
# Step 8680/10000 (87%): TrainTime=00:17:48, Loss=0.9467, TokensPerSec=33259, AvgStepTime=0.12s
# Step 8690/10000 (87%): TrainTime=00:17:50, Loss=0.9167, TokensPerSec=33261, AvgStepTime=0.12s
# Step 8700/10000 (87%): TrainTime=00:17:51, Loss=0.9724, TokensPerSec=33264, AvgStepTime=0.12s
# Step 8710/10000 (87%): TrainTime=00:17:52, Loss=0.9603, TokensPerSec=33267, AvgStepTime=0.12s
# Step 8720/10000 (87%): TrainTime=00:17:53, Loss=0.9831, TokensPerSec=33270, AvgStepTime=0.12s
# Step 8730/10000 (87%): TrainTime=00:17:54, Loss=0.9709, TokensPerSec=33273, AvgStepTime=0.12s
# Step 8740/10000 (87%): TrainTime=00:17:55, Loss=0.9573, TokensPerSec=33275, AvgStepTime=0.12s
# Step 8750/10000 (88%): TrainTime=00:17:57, Loss=0.9526, TokensPerSec=33277, AvgStepTime=0.12s
# Step 8760/10000 (88%): TrainTime=00:17:58, Loss=0.9416, TokensPerSec=33279, AvgStepTime=0.12s
# Step 8770/10000 (88%): TrainTime=00:17:59, Loss=0.9289, TokensPerSec=33273, AvgStepTime=0.12s
# Step 8780/10000 (88%): TrainTime=00:18:01, Loss=0.9359, TokensPerSec=33262, AvgStepTime=0.12s
# Step 8790/10000 (88%): TrainTime=00:18:02, Loss=0.9521, TokensPerSec=33265, AvgStepTime=0.12s
# Step 8800/10000 (88%): TrainTime=00:18:03, Loss=0.9212, TokensPerSec=33268, AvgStepTime=0.12s
# Step 8810/10000 (88%): TrainTime=00:18:04, Loss=0.9765, TokensPerSec=33270, AvgStepTime=0.12s
# Step 8820/10000 (88%): TrainTime=00:18:05, Loss=0.9634, TokensPerSec=33273, AvgStepTime=0.12s
# Step 8830/10000 (88%): TrainTime=00:18:06, Loss=0.9471, TokensPerSec=33275, AvgStepTime=0.12s
# Step 8840/10000 (88%): TrainTime=00:18:08, Loss=0.9592, TokensPerSec=33276, AvgStepTime=0.12s
# Step 8850/10000 (88%): TrainTime=00:18:09, Loss=0.9995, TokensPerSec=33278, AvgStepTime=0.12s
# Step 8860/10000 (89%): TrainTime=00:18:10, Loss=0.9933, TokensPerSec=33280, AvgStepTime=0.12s
# Step 8870/10000 (89%): TrainTime=00:18:11, Loss=0.9454, TokensPerSec=33274, AvgStepTime=0.12s
# Step 8880/10000 (89%): TrainTime=00:18:13, Loss=0.9617, TokensPerSec=33263, AvgStepTime=0.12s
# Step 8890/10000 (89%): TrainTime=00:18:14, Loss=0.9587, TokensPerSec=33265, AvgStepTime=0.12s
# Step 8900/10000 (89%): TrainTime=00:18:15, Loss=0.9539, TokensPerSec=33268, AvgStepTime=0.12s
# Step 8910/10000 (89%): TrainTime=00:18:16, Loss=0.9495, TokensPerSec=33270, AvgStepTime=0.12s
# Step 8920/10000 (89%): TrainTime=00:18:18, Loss=0.9638, TokensPerSec=33272, AvgStepTime=0.12s
# Step 8930/10000 (89%): TrainTime=00:18:19, Loss=0.9719, TokensPerSec=33275, AvgStepTime=0.12s
# Step 8940/10000 (89%): TrainTime=00:18:20, Loss=0.9823, TokensPerSec=33279, AvgStepTime=0.12s
# Step 8950/10000 (90%): TrainTime=00:18:21, Loss=0.9663, TokensPerSec=33281, AvgStepTime=0.12s
# Step 8960/10000 (90%): TrainTime=00:18:22, Loss=0.8705, TokensPerSec=33285, AvgStepTime=0.12s
# Step 8970/10000 (90%): TrainTime=00:18:23, Loss=0.9479, TokensPerSec=33282, AvgStepTime=0.12s
# Step 8980/10000 (90%): TrainTime=00:18:25, Loss=0.9569, TokensPerSec=33270, AvgStepTime=0.12s
# Step 8990/10000 (90%): TrainTime=00:18:26, Loss=0.9131, TokensPerSec=33272, AvgStepTime=0.12s
# Step 9000/10000 (90%): TrainTime=00:18:27, Loss=0.9616, TokensPerSec=33275, AvgStepTime=0.12s
# Step 9010/10000 (90%): TrainTime=00:18:29, Loss=0.9334, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9020/10000 (90%): TrainTime=00:18:30, Loss=0.9353, TokensPerSec=33279, AvgStepTime=0.12s
# Step 9030/10000 (90%): TrainTime=00:18:31, Loss=0.9469, TokensPerSec=33283, AvgStepTime=0.12s
# Step 9040/10000 (90%): TrainTime=00:18:32, Loss=0.8985, TokensPerSec=33285, AvgStepTime=0.12s
# Step 9050/10000 (90%): TrainTime=00:18:33, Loss=0.9663, TokensPerSec=33287, AvgStepTime=0.12s
# Step 9060/10000 (91%): TrainTime=00:18:34, Loss=0.9415, TokensPerSec=33288, AvgStepTime=0.12s
# Step 9070/10000 (91%): TrainTime=00:18:36, Loss=0.8811, TokensPerSec=33285, AvgStepTime=0.12s
# Step 9080/10000 (91%): TrainTime=00:18:37, Loss=0.9494, TokensPerSec=33273, AvgStepTime=0.12s
# Step 9090/10000 (91%): TrainTime=00:18:38, Loss=0.9540, TokensPerSec=33274, AvgStepTime=0.12s
# Step 9100/10000 (91%): TrainTime=00:18:40, Loss=0.9269, TokensPerSec=33276, AvgStepTime=0.12s
# Step 9110/10000 (91%): TrainTime=00:18:41, Loss=0.9230, TokensPerSec=33278, AvgStepTime=0.12s
# Step 9120/10000 (91%): TrainTime=00:18:42, Loss=0.9252, TokensPerSec=33279, AvgStepTime=0.12s
# Step 9130/10000 (91%): TrainTime=00:18:43, Loss=0.9596, TokensPerSec=33281, AvgStepTime=0.12s
# Step 9140/10000 (91%): TrainTime=00:18:44, Loss=0.9164, TokensPerSec=33283, AvgStepTime=0.12s
# Step 9150/10000 (92%): TrainTime=00:18:45, Loss=0.9873, TokensPerSec=33285, AvgStepTime=0.12s
# Step 9160/10000 (92%): TrainTime=00:18:47, Loss=0.9206, TokensPerSec=33286, AvgStepTime=0.12s
# Step 9170/10000 (92%): TrainTime=00:18:48, Loss=0.9323, TokensPerSec=33282, AvgStepTime=0.12s
# Step 9180/10000 (92%): TrainTime=00:18:50, Loss=0.9483, TokensPerSec=33270, AvgStepTime=0.12s
# Step 9190/10000 (92%): TrainTime=00:18:51, Loss=0.9446, TokensPerSec=33271, AvgStepTime=0.12s
# Step 9200/10000 (92%): TrainTime=00:18:52, Loss=0.9071, TokensPerSec=33273, AvgStepTime=0.12s
# Step 9210/10000 (92%): TrainTime=00:18:53, Loss=0.9146, TokensPerSec=33275, AvgStepTime=0.12s
# Step 9220/10000 (92%): TrainTime=00:18:54, Loss=0.9855, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9230/10000 (92%): TrainTime=00:18:56, Loss=0.9696, TokensPerSec=33280, AvgStepTime=0.12s
# Step 9240/10000 (92%): TrainTime=00:18:57, Loss=0.9464, TokensPerSec=33283, AvgStepTime=0.12s
# Step 9250/10000 (92%): TrainTime=00:18:58, Loss=0.9075, TokensPerSec=33286, AvgStepTime=0.12s
# Step 9260/10000 (93%): TrainTime=00:18:59, Loss=0.9192, TokensPerSec=33288, AvgStepTime=0.12s
# Step 9270/10000 (93%): TrainTime=00:19:00, Loss=0.9855, TokensPerSec=33283, AvgStepTime=0.12s
# Step 9280/10000 (93%): TrainTime=00:19:02, Loss=0.9356, TokensPerSec=33272, AvgStepTime=0.12s
# Step 9290/10000 (93%): TrainTime=00:19:03, Loss=0.9499, TokensPerSec=33275, AvgStepTime=0.12s
# Step 9300/10000 (93%): TrainTime=00:19:04, Loss=0.9200, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9310/10000 (93%): TrainTime=00:19:05, Loss=0.9466, TokensPerSec=33279, AvgStepTime=0.12s
# Step 9320/10000 (93%): TrainTime=00:19:07, Loss=0.9540, TokensPerSec=33281, AvgStepTime=0.12s
# Step 9330/10000 (93%): TrainTime=00:19:08, Loss=0.9412, TokensPerSec=33284, AvgStepTime=0.12s
# Step 9340/10000 (93%): TrainTime=00:19:09, Loss=0.9549, TokensPerSec=33287, AvgStepTime=0.12s
# Step 9350/10000 (94%): TrainTime=00:19:10, Loss=0.9234, TokensPerSec=33289, AvgStepTime=0.12s
# Step 9360/10000 (94%): TrainTime=00:19:11, Loss=0.9111, TokensPerSec=33291, AvgStepTime=0.12s
# Step 9370/10000 (94%): TrainTime=00:19:12, Loss=0.8975, TokensPerSec=33289, AvgStepTime=0.12s
# Step 9380/10000 (94%): TrainTime=00:19:14, Loss=0.9135, TokensPerSec=33278, AvgStepTime=0.12s
# Step 9390/10000 (94%): TrainTime=00:19:15, Loss=0.9687, TokensPerSec=33276, AvgStepTime=0.12s
# Step 9400/10000 (94%): TrainTime=00:19:17, Loss=0.9253, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9410/10000 (94%): TrainTime=00:19:18, Loss=0.9557, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9420/10000 (94%): TrainTime=00:19:19, Loss=0.9127, TokensPerSec=33279, AvgStepTime=0.12s
# Step 9430/10000 (94%): TrainTime=00:19:20, Loss=0.9392, TokensPerSec=33282, AvgStepTime=0.12s
# Step 9440/10000 (94%): TrainTime=00:19:21, Loss=0.9379, TokensPerSec=33283, AvgStepTime=0.12s
# Step 9450/10000 (94%): TrainTime=00:19:22, Loss=0.9468, TokensPerSec=33284, AvgStepTime=0.12s
# Step 9460/10000 (95%): TrainTime=00:19:24, Loss=0.9329, TokensPerSec=33286, AvgStepTime=0.12s
# Step 9470/10000 (95%): TrainTime=00:19:25, Loss=0.9486, TokensPerSec=33282, AvgStepTime=0.12s
# Step 9480/10000 (95%): TrainTime=00:19:27, Loss=0.9401, TokensPerSec=33270, AvgStepTime=0.12s
# Step 9490/10000 (95%): TrainTime=00:19:28, Loss=0.9666, TokensPerSec=33272, AvgStepTime=0.12s
# Step 9500/10000 (95%): TrainTime=00:19:29, Loss=0.9156, TokensPerSec=33274, AvgStepTime=0.12s
# Step 9510/10000 (95%): TrainTime=00:19:30, Loss=0.9471, TokensPerSec=33276, AvgStepTime=0.12s
# Step 9520/10000 (95%): TrainTime=00:19:31, Loss=0.9115, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9530/10000 (95%): TrainTime=00:19:32, Loss=0.8822, TokensPerSec=33278, AvgStepTime=0.12s
# Step 9540/10000 (95%): TrainTime=00:19:34, Loss=0.9035, TokensPerSec=33279, AvgStepTime=0.12s
# Step 9550/10000 (96%): TrainTime=00:19:35, Loss=0.9317, TokensPerSec=33280, AvgStepTime=0.12s
# Step 9560/10000 (96%): TrainTime=00:19:36, Loss=0.9168, TokensPerSec=33282, AvgStepTime=0.12s
# Step 9570/10000 (96%): TrainTime=00:19:37, Loss=0.9363, TokensPerSec=33277, AvgStepTime=0.12s
# Step 9580/10000 (96%): TrainTime=00:19:39, Loss=0.9207, TokensPerSec=33267, AvgStepTime=0.12s
# Step 9590/10000 (96%): TrainTime=00:19:40, Loss=0.9534, TokensPerSec=33269, AvgStepTime=0.12s
# Step 9600/10000 (96%): TrainTime=00:19:41, Loss=0.8992, TokensPerSec=33269, AvgStepTime=0.12s
# Step 9610/10000 (96%): TrainTime=00:19:43, Loss=0.8613, TokensPerSec=33270, AvgStepTime=0.12s
# Step 9620/10000 (96%): TrainTime=00:19:44, Loss=0.8987, TokensPerSec=33271, AvgStepTime=0.12s
# Step 9630/10000 (96%): TrainTime=00:19:45, Loss=0.9430, TokensPerSec=33273, AvgStepTime=0.12s
# Step 9640/10000 (96%): TrainTime=00:19:46, Loss=0.9109, TokensPerSec=33273, AvgStepTime=0.12s
# Step 9650/10000 (96%): TrainTime=00:19:47, Loss=0.9128, TokensPerSec=33274, AvgStepTime=0.12s
# Step 9660/10000 (97%): TrainTime=00:19:49, Loss=0.9122, TokensPerSec=33273, AvgStepTime=0.12s
# Step 9670/10000 (97%): TrainTime=00:19:50, Loss=0.8768, TokensPerSec=33264, AvgStepTime=0.12s
# Step 9680/10000 (97%): TrainTime=00:19:52, Loss=0.9197, TokensPerSec=33256, AvgStepTime=0.12s
# Step 9690/10000 (97%): TrainTime=00:19:53, Loss=0.9233, TokensPerSec=33257, AvgStepTime=0.12s
# Step 9700/10000 (97%): TrainTime=00:19:54, Loss=0.9502, TokensPerSec=33259, AvgStepTime=0.12s
# Step 9710/10000 (97%): TrainTime=00:19:55, Loss=0.9284, TokensPerSec=33261, AvgStepTime=0.12s
# Step 9720/10000 (97%): TrainTime=00:19:56, Loss=0.8950, TokensPerSec=33261, AvgStepTime=0.12s
# Step 9730/10000 (97%): TrainTime=00:19:58, Loss=0.9178, TokensPerSec=33262, AvgStepTime=0.12s
# Step 9740/10000 (97%): TrainTime=00:19:59, Loss=0.8983, TokensPerSec=33264, AvgStepTime=0.12s
# Step 9750/10000 (98%): TrainTime=00:20:00, Loss=0.8912, TokensPerSec=33265, AvgStepTime=0.12s
# Step 9760/10000 (98%): TrainTime=00:20:01, Loss=0.9210, TokensPerSec=33266, AvgStepTime=0.12s
# Step 9770/10000 (98%): TrainTime=00:20:03, Loss=0.9182, TokensPerSec=33255, AvgStepTime=0.12s
# Step 9780/10000 (98%): TrainTime=00:20:04, Loss=0.9113, TokensPerSec=33251, AvgStepTime=0.12s
# Step 9790/10000 (98%): TrainTime=00:20:05, Loss=0.9420, TokensPerSec=33253, AvgStepTime=0.12s
# Step 9800/10000 (98%): TrainTime=00:20:07, Loss=0.8922, TokensPerSec=33254, AvgStepTime=0.12s
# Step 9810/10000 (98%): TrainTime=00:20:08, Loss=0.8862, TokensPerSec=33256, AvgStepTime=0.12s
# Step 9820/10000 (98%): TrainTime=00:20:09, Loss=0.8942, TokensPerSec=33258, AvgStepTime=0.12s
# Step 9830/10000 (98%): TrainTime=00:20:10, Loss=0.8850, TokensPerSec=33260, AvgStepTime=0.12s
# Step 9840/10000 (98%): TrainTime=00:20:11, Loss=0.8535, TokensPerSec=33262, AvgStepTime=0.12s
# Step 9850/10000 (98%): TrainTime=00:20:12, Loss=0.9281, TokensPerSec=33264, AvgStepTime=0.12s
# Step 9860/10000 (99%): TrainTime=00:20:14, Loss=0.8876, TokensPerSec=33265, AvgStepTime=0.12s
# Step 9870/10000 (99%): TrainTime=00:20:15, Loss=0.9107, TokensPerSec=33254, AvgStepTime=0.12s
# Step 9880/10000 (99%): TrainTime=00:20:17, Loss=0.8712, TokensPerSec=33251, AvgStepTime=0.12s
# Step 9890/10000 (99%): TrainTime=00:20:18, Loss=0.8727, TokensPerSec=33253, AvgStepTime=0.12s
# Step 9900/10000 (99%): TrainTime=00:20:19, Loss=0.8870, TokensPerSec=33255, AvgStepTime=0.12s
# Step 9910/10000 (99%): TrainTime=00:20:20, Loss=0.8582, TokensPerSec=33257, AvgStepTime=0.12s
# Step 9920/10000 (99%): TrainTime=00:20:21, Loss=0.8819, TokensPerSec=33259, AvgStepTime=0.12s
# Step 9930/10000 (99%): TrainTime=00:20:22, Loss=0.9715, TokensPerSec=33261, AvgStepTime=0.12s
# Step 9940/10000 (99%): TrainTime=00:20:23, Loss=0.8982, TokensPerSec=33263, AvgStepTime=0.12s
# Step 9950/10000 (100%): TrainTime=00:20:25, Loss=0.8735, TokensPerSec=33266, AvgStepTime=0.12s
# Step 9960/10000 (100%): TrainTime=00:20:26, Loss=0.8847, TokensPerSec=33270, AvgStepTime=0.12s
# Step 9970/10000 (100%): TrainTime=00:20:27, Loss=0.9161, TokensPerSec=33262, AvgStepTime=0.12s
# Step 9980/10000 (100%): TrainTime=00:20:29, Loss=0.9052, TokensPerSec=33257, AvgStepTime=0.12s
# Step 9990/10000 (100%): TrainTime=00:20:30, Loss=0.8990, TokensPerSec=33260, AvgStepTime=0.12s
# Step 10000/10000 (100%): TrainTime=00:20:31, Loss=0.8799, TokensPerSec=33263, AvgStepTime=0.12s

# %%
@torch.no_grad
def generate(
  model: nn.Module,
  vocab: Vocabulary,
  input: str,
  new_tokens: int,
):
  idx = vocab.encode(input)
  idx = torch.tensor(idx, dtype=torch.long, device=device)
  idx = einops.rearrange(idx, "... -> 1 ...")

  for t in range(new_tokens):
    ctx = idx[:, -seq_len:]

    logits = model(ctx)

    next_logits = logits[:, -1, :]

    next_probs = torch.softmax(next_logits, dim=-1)

    next_idx = torch.multinomial(next_probs, num_samples=1)
    # append sampled index to the running sequence and continue
    idx = torch.cat((idx, next_idx), dim=1)

  idx = idx.tolist()[0]
  output = vocab.decode(idx)
  return output

output = generate(
    model,
    vocab,
    "H",
    1000,
)
print(output)
# Out:
# HARD III:
# Here letters thirvingman:
# Directitude and victory purpose!
#
# First Senatol:
# Men's eyes will or powerful unfold floveth.
#
# DUKE VINCENTIO:
# Pray, no, no, not to me well.
#
# PETRUCHIO:
# Faith, marquess, and come to your grace powerful
# We have unducationed by the dgown, carce with and give
# not into a village hap into your souls,
# In warnals dagger, and got love, kill'd contried
# Than the brunts. For what I call attend,
# Insug hacks are true kneeping, to make the queen,
# We wish she sers of the Tare of onestable,
# Nor that is the match of pale beloud,
# Of the dukedom, where he is my body's destisity.
#
# LADY ANNE:
# I will tell me, if I remember it were all
# on the hundred, and disease it is,
# Nor done immoder, up with Romeo.
#
# First Senator:
# You have done, no denerate commends.
# Do you have with her? here chesicourse he has discovered thy watery,
# With that runfidence into harms, and does he
# Doth log from your suit on your great at the
# shed but as is taunting, our before thou
# Then denying the educati
